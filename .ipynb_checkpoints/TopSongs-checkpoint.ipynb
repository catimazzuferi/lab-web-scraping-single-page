# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "http://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# soup

# %%
#soup.select('body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper > div')

# %%
song_info = []

for song in soup.find_all('p', class_='title-artist'):
    song_name = song.find('cite', class_='title').get_text()
    artist_name = song.find('em', class_='artist').get_text()
    song_info.append((song_name, artist_name))

print("Songs:", song_info)
# Out:
# Songs: [('Lovin On Me', 'Jack Harlow'), ('Lil Boo Thang', 'Paul Russell'), ('I Remember Everything (feat. Kacey Musgraves)', 'Zach Bryan'), ('White Horse', 'Chris Stapleton'), ('Save Me (with Lainey Wilson)', 'Jelly Roll'), ('Need A Favor', 'Jelly Roll'), ('Cruel Summer', 'Taylor Swift'), ('90s Rap Mashup', 'Austin Williams'), ('Thinkin’ Bout Me', 'Morgan Wallen'), ('Daylight', 'David Kushner'), ('Standing Next to You', 'Jung Kook'), ('Christmas / Sarajevo 12/24 (Instrumental)', 'Trans-Siberian Orchestra'), ('All I Want for Christmas Is You', 'Mariah Carey'), ('Lovin On Me', 'Jack Harlow'), ('Lose Control', 'Teddy Swims'), ('Houdini', 'Dua Lipa'), ('3D', 'Jung Kook & Jack Harlow'), ('Fast Car', 'Luke Combs'), ('Last Night', 'Morgan Wallen'), ('greedy', 'Tate McRae'), ('Now And Then', 'The Beatles'), ("Rockin' Around the Christmas Tree (Single)", 'Brenda Lee'), ('Standing Next to You (Band Version)', 'Jung Kook'), ('Sin So Sweet', 'Warren Zeiders'), ('Water', 'Tyla'), ('Standing Next to You (Future Funk Remix)', 'Jung Kook'), ('Lover', 'Taylor Swift'), ('Where the Wild Things Are', 'Luke Combs'), ('Standing Next to You (PBR&B Remix)', 'Jung Kook'), ('Standing Next to You (Slow Jam Remix)', 'Jung Kook'), ('Standing Next to You (Holiday Remix)', 'Jung Kook'), ('Standing Next to You (Latin Trap Remix)', 'Jung Kook'), ('Standing Next to You (Instrumental)', 'Jung Kook'), ('Paint The Town Red', 'Doja Cat'), ('To Be A Man (feat. Darius Rucker)', 'Dax'), ('Rich Men North of Richmond', 'Oliver Anthony Music'), ('Karma', 'Taylor Swift'), ('Wild Ones (Extended Version)', 'Jessie Murph & Jelly Roll'), ('Don’t Blame Me', 'Taylor Swift'), ('Unstoppable', 'Sia'), ('Wrap Me Up', 'Jimmy Fallon & Meghan Trainor'), ('Around Me the Cold Night', 'Luminara Stellaris'), ('Oral', 'Björk & ROSALÍA'), ('The Christmas Song (Merry Christmas to You)', 'Nat "King" Cole'), ('Can’t Catch Me Now (from The Hunger Games: The Ballad of Songbirds & Snakes)', 'Olivia Rodrigo'), ('Snowman', 'Sia'), ("Is It Over Now? (Taylor's Version) [From The Vault]", 'Taylor Swift'), ('Anti-Hero', 'Taylor Swift'), ('Save Me', 'Jelly Roll'), ('Used To Be Young', 'Miley Cyrus'), ('Watermelon Moonshine', 'Lainey Wilson'), ('Fairytale Of Philadelphia', 'The Philly Specials, Jason Kelce & Travis Kelce'), ('MONACO', 'Bad Bunny'), ('Love Story (Taylor’s Version)', 'Taylor Swift'), ('Seven (Explicit Ver.)', 'Jung Kook & Latto'), ('Better Place (From TROLLS Band Together)', '*NSYNC & Justin Timberlake'), ('Next Winter I Will Wait for You Forever', 'Luminara Stellaris'), ('The Painter', 'Cody Johnson'), ('You Belong With Me (Taylor’s Version)', 'Taylor Swift'), ('Fancy Like Christmas', 'Walker Hayes'), ("Flyin' Pass (Single)", 'Caldwell'), ('Tennessee Whiskey', 'Chris Stapleton'), ('Son Of A Sinner', 'Jelly Roll'), ('Wizards in Winter (Instrumental)', 'Trans-Siberian Orchestra'), ('Talking to the Moon', 'Bruno Mars'), ('Calm Down', 'Rema & Selena Gomez'), ('Paper Rings', 'Taylor Swift'), ('Dance The Night', 'Dua Lipa'), ('Look What You Made Me Do', 'Taylor Swift'), ("Style (Taylor's Version)", 'Taylor Swift'), ('Islands In the Stream', 'Dolly Parton & Kenny Rogers'), ("The Chipmunk Song (Christmas Don't Be Late)", 'Alvin & The Chipmunks'), ('Flowers', 'Miley Cyrus'), ('Even Though I Know You', 'Luminara Stellaris'), ('TRUCK BED', 'HARDY'), ('Evil Ways (feat. J. Cole)', 'Drake'), ('exes', 'Tate McRae'), ('Presha', '2 Chainz & Lil Wayne'), ("A Mad Russian's Christmas (Instrumental)", 'Trans-Siberian Orchestra'), ('...Ready For It?', 'Taylor Swift'), ('Dial Drunk', 'Noah Kahan & Post Malone'), ('A Lot More Free', 'Max McNown'), ('Last Christmas (Single Version)', 'Wham!'), ("Something in the Orange (Z&E's Version)", 'Zach Bryan'), ('What Was I Made For? [From The Motion Picture "Barbie"]', 'Billie Eilish'), ('You Broke My Heart', 'Drake'), ('World on Fire', 'Nate Smith'), ('In the Sky a White Cloud Drifted Lazily', 'Luminara Stellaris'), ('White Christmas', 'Bing Crosby'), ('ONE MORE TIME',  ...

# %%
top_songs = pd.DataFrame(song_info, columns=['Song Name', 'Artist Name'])

top_songs
# Out:
#                                         Song Name  \
# 0                                     Lovin On Me
# 1                                   Lil Boo Thang
# 2   I Remember Everything (feat. Kacey Musgraves)
# 3                                     White Horse
# 4                    Save Me (with Lainey Wilson)
# ..                                            ...
# 95                                             G6
# 96                                      Gratitude
# 97                                      Everleave
# 98                                      Good Good
# 99   Surround Sound (feat. 21 Savage & Baby Tate)
#
#                          Artist Name
# 0                        Jack Harlow
# 1                       Paul Russell
# 2                         Zach Bryan
# 3                    Chris Stapleton
# 4                         Jelly Roll
# ..                               ...
# 95              2 Chainz & Lil Wayne
# 96                      Brandon Lake
# 97                     Alexandra Kay
# 98  USHER, Summer Walker & 21 Savage
# 99                               JID
#
# [100 rows x 2 columns]

# %%
import random
def recomendar(top_songs, cancion_ingresada):
    cancion_ingresada = cancion_ingresada.lower()
    top_songs['Song Name'] = top_songs['Song Name'].str.lower()
    if cancion_ingresada in top_songs['Song Name'].values:
        canciones_disponibles = top_songs[top_songs['Song Name'] != cancion_ingresada]
        cancion_recomendada = random.choice(canciones_disponibles['Song Name'].values)
        
        return f"Te recomiendo escuchar '{cancion_recomendada}' de {top_songs.loc[top_songs['Song Name'] == cancion_recomendada, 'Artist Name'].values[0]}."
    else:
        return "Lo siento, no puedo recomendar una canción."


cancion_ingresada = input("Ingresa el nombre de una canción: ")
resultado = recomendar(top_songs, cancion_ingresada)
print(resultado)
# Out:
# Ingresa el nombre de una canción: j
# Lo siento, no puedo recomendar una canción.

# %%
#LAB 2

# %%
url2 = 'https://www.rollingstone.com/music/music-lists/best-songs-of-all-time-1224767/daddy-yankee-feat-glory-gasolina-1225288/'

# %%
response2 = requests.get(url2)
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.content, "html.parser")

# %%
#soup2

# %%
#soup2.select('#post-1224767 > div > div.a-featured-list-grid__content.lrv-a-wrapper')

# %%
h2_elements = soup2.find_all('h2')
results = [element.get_text(strip=True) for element in h2_elements]

top_songs = pd.DataFrame(song_info, columns=['Song Name', 'Artist Name'])

for element in h2_elements:
    text = element.get_text(strip=True)
    parts = [part.strip() for part in text.split(',')]

    if len(parts) == 2:
        artist, song = parts
        artist, song = [part.replace("‘", "").replace("’", "") for part in parts]
        top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
    else:
        print('xd')

top_songs
# Out:
# xd
# xd
# xd
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/3942124077.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top_songs = top_songs.append({'Artist Name': artist, 'Song Name': song}, ignore_index=True)
#                                          Song Name      Artist Name
# 0                                      Lovin On Me      Jack Harlow
# 1                                    Lil Boo Thang     Paul Russell
# 2    I Remember Everything (feat. Kacey Musgraves)       Zach Bryan
# 3                                      White Horse  Chris Stapleton
# 4                     Save Me (with Lainey Wilson)       Jelly Roll
# ..                                             ...              ...
# 145                        Smells Like Teen Spirit          Nirvana
# 146                           Like a Rolling Stone        Bob Dylan
# 147                         A Change Is Gonna Come        Sam Cooke
# 148                                Fight the Power     Public Enemy
# 149                                        Respect  Aretha Franklin
#
# [150 rows x 2 columns]

# %%
import random
def recomendar(top_songs, cancion_ingresada):
    cancion_ingresada = cancion_ingresada.lower()
    top_songs['Song Name'] = top_songs['Song Name'].str.lower()
    if cancion_ingresada in top_songs['Song Name'].values:
        canciones_disponibles = top_songs[top_songs['Song Name'] != cancion_ingresada]
        cancion_recomendada = random.choice(canciones_disponibles['Song Name'].values)
        
        return f"Te recomiendo escuchar '{cancion_recomendada}' de {top_songs.loc[top_songs['Song Name'] == cancion_recomendada, 'Artist Name'].values[0]}."
    else:
        return "Lo siento, no puedo recomendar una canción."


cancion_ingresada = input("Ingresa el nombre de una canción: ")
resultado = recomendar(top_songs, cancion_ingresada)
print(resultado)
# Out:
# Ingresa el nombre de una canción: j
# Lo siento, no puedo recomendar una canción.

# %% [markdown]
# # API Wrappers

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
import pandas as pd
from pandas import json_normalize

# %%
# we will use our 'first paid music' playlist as an example:
playlist = sp.user_playlist_tracks("spotify", "5xqpyfZyS1DVysoevdVyEn")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5xqpyfZyS1DVysoevdVyEn/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xU878Z1QtBldR7ru9owdU'},
#        'href': 'https://api.spotify.com/v1/artists/1xU878Z1QtBldR7ru9owdU',
#        'id': '1xU878Z1QtBldR7ru9owdU',
#        'name': 'Phoenix',
#        'type': 'artist',
#        'uri': 'spotify:artist:1xU878Z1QtBldR7ru9owdU'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5MBUL8d9FAYCCMrogOFX68'},
#      'href': 'https://api.spotify.com/v1/albums/5MBUL8d9FAYCCMrogOFX68',
#      'id': '5MBUL8d9FAYCCMrogOFX68',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fd7121d725a0e4aafd4fe785',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fd7121d725a0e4aafd4fe785',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fd7121d725a0e4aafd4fe785',
#        'width': 64}],
#      'name': 'United',
#      'release_date': '2000-03-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5MBUL8d9FAYCCMrogOFX68'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xU878Z1QtBldR7ru9owdU'},
#       'href': 'https://api.spotify.com/v1/artists/1xU878Z1QtBldR7ru9owdU',
#       'id': '1xU878Z1QtBldR7ru9owdU',
#       'name': 'Phoenix',
#       'type': 'artist',
#       'uri': 'spotify:artist:1xU878Z1QtBldR7ru9owdU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 266600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRS639900098'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AA8xNhDC0MpqwkGX3EP5V'},
#     'href': 'https://api.spotify.com/v1/tracks/3AA8xNhDC0MpqwkGX3EP5V',
#     'id': '3AA8xNhDC0MpqwkGX3EP5V',
#     'is_local': False,
#     'name': 'If I Ever Feel Better',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eb1e1d7972172e23859bc5f0e6c7ec7f63ced943?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3AA8xNhDC0MpqwkGX3EP5V'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oWyxHNcxMcrvNIHMX2apR'},
#        'href': 'https://api.spotify.com/v1/artists/2oWyxHNcxMcrvNIHMX2apR',
#        'id': '2oWyxHNcxMcrvNIHMX2apR',
#        'name': 'Radio 4',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oWyxHNcxMcrvNIHMX2apR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'MK',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Maw9mmnklMBmaLrl1W6v7'},
#      'href': 'https://api.spotify.com/v1/albums/6Maw9mmnklMBmaLrl1W6v7',
#      'id': '6Maw9mmnklMBmaLrl1W6v7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735bf2a2eae7fd3bb2bdf17ecc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025bf2a2eae7fd3bb2bdf17ecc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515bf2a2eae7fd3bb2bdf17ecc',
#        'width': 64}],
#      'name': 'Dance To The Underground',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:6Maw9mmnklMBmaLrl1W6v7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oWyxHNcxMcrvNIHMX2apR'},
#       'href': 'https://api.spotify.com/v1/artists/2oWyxHNcxMcrvNIHMX2apR',
#       'id': '2oWyxHNcxMcrvNIHMX2apR',
#       'name': 'Radio 4',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oWyxHNcxMcrvNIHMX2apR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 243213,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US2B30405301'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2i8lRhmZNKaM1ypHwRybuD'},
#     'href': 'https://api.spotify.com/v1/tracks/2i8lRhmZNKaM1ypHwRybuD',
#     'id': '2i8lRhmZNKaM1ypHwRybuD',
#     'is_local': False,
#     'name': 'Dance To The Underground',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bf9953e29d806a33ab402ec37ccbeef2469fced1?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2i8lRhmZNKaM1ypHwRybuD'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UyhhfLOvfLs7ZhzsAaNC3'},
#        'href': 'https://api.spotify.com/v1/artists/2UyhhfLOvfLs7ZhzsAaNC3',
#        'id': '2UyhhfLOvfLs7ZhzsAaNC3',
#        'name': 'Mount Sims',
#        'type': 'artist',
#        'uri': 'spotify:artist:2UyhhfLOvfLs7ZhzsAaNC3'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'MK',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6IvwFVN9YI9Bokka32c80b'},
#      'href': 'https://api.spotify.com/v1/albums/6IvwFVN9YI9Bokka32c80b',
#      'id': '6IvwFVN9YI9Bokka32c80b',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b07c5c0cb2593a633e8fbc72',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b07c5c0cb2593a633e8fbc72',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b07c5c0cb2593a633e8fbc72',
#        'width': 64}],
#      'name': 'UltraSex',
#      'release_date': '2002',
#      'release_date_precision': 'year',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6IvwFVN9YI9Bokka32c80b'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UyhhfLOvfLs7ZhzsAaNC3'},
#       'href': 'https://api.spotify.com/v1/artists/2UyhhfLOvfLs7ZhzsAaNC3',
#       'id': '2UyhhfLOvfLs7ZhzsAaNC3',
#       'name': 'Mount Sims',
#       'type': 'artist',
#       'uri': 'spotify:artist:2UyhhfLOvfLs7ZhzsAaNC3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 234000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US25T9915124'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4flxgPC0426CEeSrzQIic0'},
#     'href': 'https://api.spotify.com/v1/tracks/4flxgPC0426CEeSrzQIic0',
#     'id': '4flxgPC0426CEeSrzQIic0',
#     'is_local': False,
#     'name': 'How We Do',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7b8c0e7b8498eaf4d2205dc6ecffd16dfb35e631?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4flxgPC0426CEeSrzQIic0'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1gkSl4XpHIHI4I1WQbfXOE'},
#        'href': 'https://api.spotify.com/v1/artists/1gkSl4XpHIHI4I1WQbfXOE',
#        'id': '1gkSl4XpHIHI4I1WQbfXOE',
#        'name': 'Peaches',
#        'type': 'artist',
#        'uri': 'spotify:artist:1gkSl4XpHIHI4I1WQbfXOE'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5sgLqGnrMemtvQ5c4GUhab'},
#      'href': 'https://api.spotify.com/v1/albums/5sgLqGnrMemtvQ5c4GUhab',
#      'id': '5sgLqGnrMemtvQ5c4GUhab',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388170b093550ed085d9f12f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288170b093550ed085d9f12f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188170b093550ed085d9f12f4',
#        'width': 64}],
#      'name': 'The Teaches of Peaches',
#      'release_date': '2002-10-08',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5sgLqGnrMemtvQ5c4GUhab'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1gkSl4XpHIHI4I1WQbfXOE'},
#       'href': 'https://api.spotify.com/v1/artists/1gkSl4XpHIHI4I1WQbfXOE',
#       'id': '1gkSl4XpHIHI4I1WQbfXOE',
#       'name': 'Peaches',
#       'type': 'artist',
#       'uri': 'spotify:artist:1gkSl4XpHIHI4I1WQbfXOE'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 250693,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBBKS0000479'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1XHFob24QklIXtLRopKirJ'},
#     'href': 'https://api.spotify.com/v1/tracks/1XHFob24QklIXtLRopKirJ',
#     'id': '1XHFob24QklIXtLRopKirJ',
#     'is_local': False,
#     'name': 'Fuck the Pain Away',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1XHFob24QklIXtLRopKirJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GpAL7oEFD37IJDOOiirqy'},
#        'href': 'https://api.spotify.com/v1/artists/3GpAL7oEFD37IJDOOiirqy',
#        'id': '3GpAL7oEFD37IJDOOiirqy',
#        'name': 'Zongamin',
#        'type': 'artist',
#        'uri': 'spotify:artist:3GpAL7oEFD37IJDOOiirqy'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Syz0qLiM7dkDQuUzrpkU2'},
#      'href': 'https://api.spotify.com/v1/albums/5Syz0qLiM7dkDQuUzrpkU2',
#      'id': '5Syz0qLiM7dkDQuUzrpkU2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730af76052252a60066bf01e2e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020af76052252a60066bf01e2e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510af76052252a60066bf01e2e',
#        'width': 64}],
#      'name': 'Zongamin',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5Syz0qLiM7dkDQuUzrpkU2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GpAL7oEFD37IJDOOiirqy'},
#       'href': 'https://api.spotify.com/v1/artists/3GpAL7oEFD37IJDOOiirqy',
#       'id': '3GpAL7oEFD37IJDOOiirqy',
#       'name': 'Zongamin',
#       'type': 'artist',
#       'uri': 'spotify:artist:3GpAL7oEFD37IJDOOiirqy'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 224800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS0200501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4JB847zlgViLq8tJIzRsZy'},
#     'href': 'https://api.spotify.com/v1/tracks/4JB847zlgViLq8tJIzRsZy',
#     'id': '4JB847zlgViLq8tJIzRsZy',
#     'is_local': False,
#     'name': 'Street Surgery 2',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4JB847zlgViLq8tJIzRsZy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5R7K1GezC0jy24v1R2n4x3'},
#        'href': 'https://api.spotify.com/v1/artists/5R7K1GezC0jy24v1R2n4x3',
#        'id': '5R7K1GezC0jy24v1R2n4x3',
#        'name': 'Fischerspooner',
#        'type': 'artist',
#        'uri': 'spotify:artist:5R7K1GezC0jy24v1R2n4x3'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3OCiJ6mbOzJdzTrk8R9hy2'},
#      'href': 'https://api.spotify.com/v1/albums/3OCiJ6mbOzJdzTrk8R9hy2',
#      'id': '3OCiJ6mbOzJdzTrk8R9hy2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cf3b2ef859bb7527936c1c1f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cf3b2ef859bb7527936c1c1f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cf3b2ef859bb7527936c1c1f',
#        'width': 64}],
#      'name': '#1',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3OCiJ6mbOzJdzTrk8R9hy2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5R7K1GezC0jy24v1R2n4x3'},
#       'href': 'https://api.spotify.com/v1/artists/5R7K1GezC0jy24v1R2n4x3',
#       'id': '5R7K1GezC0jy24v1R2n4x3',
#       'name': 'Fischerspooner',
#       'type': 'artist',
#       'uri': 'spotify:artist:5R7K1GezC0jy24v1R2n4x3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 288306,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFS20200002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vyKSb9sAdXl0kQ1KnS9fY'},
#     'href': 'https://api.spotify.com/v1/tracks/3vyKSb9sAdXl0kQ1KnS9fY',
#     'id': '3vyKSb9sAdXl0kQ1KnS9fY',
#     'is_local': False,
#     'name': 'Emerge',
#     'popularity': 51,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3vyKSb9sAdXl0kQ1KnS9fY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#        'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#        'id': '5yV1qdnmxyIYiSFB02wpDj',
#        'name': 'The Postal Service',
#        'type': 'artist',
#        'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19AxGebIDoa4PrkvuZ2ACZ'},
#      'href': 'https://api.spotify.com/v1/albums/19AxGebIDoa4PrkvuZ2ACZ',
#      'id': '19AxGebIDoa4PrkvuZ2ACZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ef6c8ce9a3449b0d8cc1f81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ef6c8ce9a3449b0d8cc1f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ef6c8ce9a3449b0d8cc1f81',
#        'width': 64}],
#      'name': 'Give Up',
#      'release_date': '2003-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:19AxGebIDoa4PrkvuZ2ACZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#       'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#       'id': '5yV1qdnmxyIYiSFB02wpDj',
#       'name': 'The Postal Service',
#       'type': 'artist',
#       'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 266346,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSUB0300120'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3iDK8BAaBUatPR84gdfa9g'},
#     'href': 'https://api.spotify.com/v1/tracks/3iDK8BAaBUatPR84gdfa9g',
#     'id': '3iDK8BAaBUatPR84gdfa9g',
#     'is_local': False,
#     'name': 'Such Great Heights',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3iDK8BAaBUatPR84gdfa9g'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#        'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#        'id': '5yV1qdnmxyIYiSFB02wpDj',
#        'name': 'The Postal Service',
#        'type': 'artist',
#        'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19AxGebIDoa4PrkvuZ2ACZ'},
#      'href': 'https://api.spotify.com/v1/albums/19AxGebIDoa4PrkvuZ2ACZ',
#      'id': '19AxGebIDoa4PrkvuZ2ACZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ef6c8ce9a3449b0d8cc1f81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ef6c8ce9a3449b0d8cc1f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ef6c8ce9a3449b0d8cc1f81',
#        'width': 64}],
#      'name': 'Give Up',
#      'release_date': '2003-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:19AxGebIDoa4PrkvuZ2ACZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#       'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#       'id': '5yV1qdnmxyIYiSFB02wpDj',
#       'name': 'The Postal Service',
#       'type': 'artist',
#       'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 284293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSUB0300119'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Bf5C7RkyXTqE1h3Q8KZJ7'},
#     'href': 'https://api.spotify.com/v1/tracks/5Bf5C7RkyXTqE1h3Q8KZJ7',
#     'id': '5Bf5C7RkyXTqE1h3Q8KZJ7',
#     'is_local': False,
#     'name': 'The District Sleeps Alone Tonight',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Bf5C7RkyXTqE1h3Q8KZJ7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#        'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#        'id': '5yV1qdnmxyIYiSFB02wpDj',
#        'name': 'The Postal Service',
#        'type': 'artist',
#        'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19AxGebIDoa4PrkvuZ2ACZ'},
#      'href': 'https://api.spotify.com/v1/albums/19AxGebIDoa4PrkvuZ2ACZ',
#      'id': '19AxGebIDoa4PrkvuZ2ACZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ef6c8ce9a3449b0d8cc1f81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ef6c8ce9a3449b0d8cc1f81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ef6c8ce9a3449b0d8cc1f81',
#        'width': 64}],
#      'name': 'Give Up',
#      'release_date': '2003-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:19AxGebIDoa4PrkvuZ2ACZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5yV1qdnmxyIYiSFB02wpDj'},
#       'href': 'https://api.spotify.com/v1/artists/5yV1qdnmxyIYiSFB02wpDj',
#       'id': '5yV1qdnmxyIYiSFB02wpDj',
#       'name': 'The Postal Service',
#       'type': 'artist',
#       'uri': 'spotify:artist:5yV1qdnmxyIYiSFB02wpDj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 261253,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSUB0300121'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LEsGGRUrZZhLPFoxeioHr'},
#     'href': 'https://api.spotify.com/v1/tracks/0LEsGGRUrZZhLPFoxeioHr',
#     'id': '0LEsGGRUrZZhLPFoxeioHr',
#     'is_local': False,
#     'name': 'Sleepin In',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0LEsGGRUrZZhLPFoxeioHr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNadaO5ZZLVJdqDIVVIua'},
#        'href': 'https://api.spotify.com/v1/artists/4xNadaO5ZZLVJdqDIVVIua',
#        'id': '4xNadaO5ZZLVJdqDIVVIua',
#        'name': 'Electric Six',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xNadaO5ZZLVJdqDIVVIua'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3SHETp4kEDcejJ7yRJzjKS'},
#      'href': 'https://api.spotify.com/v1/albums/3SHETp4kEDcejJ7yRJzjKS',
#      'id': '3SHETp4kEDcejJ7yRJzjKS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733e1361ca3ec392dc2586bf76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023e1361ca3ec392dc2586bf76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513e1361ca3ec392dc2586bf76',
#        'width': 64}],
#      'name': 'Fire',
#      'release_date': '2003-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3SHETp4kEDcejJ7yRJzjKS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNadaO5ZZLVJdqDIVVIua'},
#       'href': 'https://api.spotify.com/v1/artists/4xNadaO5ZZLVJdqDIVVIua',
#       'id': '4xNadaO5ZZLVJdqDIVVIua',
#       'name': 'Electric Six',
#       'type': 'artist',
#       'uri': 'spotify:artist:4xNadaO5ZZLVJdqDIVVIua'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 214600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS0200539'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LtIW2Y5NbZnMlUJbiviQ6'},
#     'href': 'https://api.spotify.com/v1/tracks/6LtIW2Y5NbZnMlUJbiviQ6',
#     'id': '6LtIW2Y5NbZnMlUJbiviQ6',
#     'is_local': False,
#     'name': 'Danger! High Voltage - Soulchild Radio Mix',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6LtIW2Y5NbZnMlUJbiviQ6'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNadaO5ZZLVJdqDIVVIua'},
#        'href': 'https://api.spotify.com/v1/artists/4xNadaO5ZZLVJdqDIVVIua',
#        'id': '4xNadaO5ZZLVJdqDIVVIua',
#        'name': 'Electric Six',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xNadaO5ZZLVJdqDIVVIua'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3SHETp4kEDcejJ7yRJzjKS'},
#      'href': 'https://api.spotify.com/v1/albums/3SHETp4kEDcejJ7yRJzjKS',
#      'id': '3SHETp4kEDcejJ7yRJzjKS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733e1361ca3ec392dc2586bf76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023e1361ca3ec392dc2586bf76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513e1361ca3ec392dc2586bf76',
#        'width': 64}],
#      'name': 'Fire',
#      'release_date': '2003-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3SHETp4kEDcejJ7yRJzjKS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNadaO5ZZLVJdqDIVVIua'},
#       'href': 'https://api.spotify.com/v1/artists/4xNadaO5ZZLVJdqDIVVIua',
#       'id': '4xNadaO5ZZLVJdqDIVVIua',
#       'name': 'Electric Six',
#       'type': 'artist',
#       'uri': 'spotify:artist:4xNadaO5ZZLVJdqDIVVIua'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 140906,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS0200646'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6s9iK4Hf5nLhdDMCnkDV3T'},
#     'href': 'https://api.spotify.com/v1/tracks/6s9iK4Hf5nLhdDMCnkDV3T',
#     'id': '6s9iK4Hf5nLhdDMCnkDV3T',
#     'is_local': False,
#     'name': 'Gay Bar',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6s9iK4Hf5nLhdDMCnkDV3T'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5kwHgbzNHq1iHkUSrAmjjQ'},
#        'href': 'https://api.spotify.com/v1/artists/5kwHgbzNHq1iHkUSrAmjjQ',
#        'id': '5kwHgbzNHq1iHkUSrAmjjQ',
#        'name': 'Audio Bullys',
#        'type': 'artist',
#        'uri': 'spotify:artist:5kwHgbzNHq1iHkUSrAmjjQ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0m64hKTbSbiPam3q2wDFWB'},
#      'href': 'https://api.spotify.com/v1/albums/0m64hKTbSbiPam3q2wDFWB',
#      'id': '0m64hKTbSbiPam3q2wDFWB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd28e09af181ec53ab960998',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd28e09af181ec53ab960998',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd28e09af181ec53ab960998',
#        'width': 64}],
#      'name': 'Ego War',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0m64hKTbSbiPam3q2wDFWB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5kwHgbzNHq1iHkUSrAmjjQ'},
#       'href': 'https://api.spotify.com/v1/artists/5kwHgbzNHq1iHkUSrAmjjQ',
#       'id': '5kwHgbzNHq1iHkUSrAmjjQ',
#       'name': 'Audio Bullys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5kwHgbzNHq1iHkUSrAmjjQ'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 210800,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBDCG0200358'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5rDFRvwao7MFzuhrBTkWMQ'},
#     'href': 'https://api.spotify.com/v1/tracks/5rDFRvwao7MFzuhrBTkWMQ',
#     'id': '5rDFRvwao7MFzuhrBTkWMQ',
#     'is_local': False,
#     'name': "We Don't Care",
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5rDFRvwao7MFzuhrBTkWMQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YrKBkKSVeqDamzBPWVnSJ'},
#        'href': 'https://api.spotify.com/v1/artists/4YrKBkKSVeqDamzBPWVnSJ',
#        'id': '4YrKBkKSVeqDamzBPWVnSJ',
#        'name': 'Basement Jaxx',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YrKBkKSVeqDamzBPWVnSJ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5bRWjHhJ3LU8QJ3hzE6ho8'},
#      'href': 'https://api.spotify.com/v1/albums/5bRWjHhJ3LU8QJ3hzE6ho8',
#      'id': '5bRWjHhJ3LU8QJ3hzE6ho8',
#      'images': [{'height': 640,
# ...
#        'type': 'artist',
#        'uri': 'spotify:artist:7M6zxq59QM0CMvvYprtzOZ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6baHSr3TiziN6yvOQq0qBS'},
#      'href': 'https://api.spotify.com/v1/albums/6baHSr3TiziN6yvOQq0qBS',
#      'id': '6baHSr3TiziN6yvOQq0qBS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cf6b1d283f1f391dda0e001b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cf6b1d283f1f391dda0e001b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cf6b1d283f1f391dda0e001b',
#        'width': 64}],
#      'name': 'A Strange Education',
#      'release_date': '2007-03-26',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6baHSr3TiziN6yvOQq0qBS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7M6zxq59QM0CMvvYprtzOZ'},
#       'href': 'https://api.spotify.com/v1/artists/7M6zxq59QM0CMvvYprtzOZ',
#       'id': '7M6zxq59QM0CMvvYprtzOZ',
#       'name': 'The Cinematics',
#       'type': 'artist',
#       'uri': 'spotify:artist:7M6zxq59QM0CMvvYprtzOZ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 324040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USTV10600215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qlMTivCjISCkR3gLAB3tc'},
#     'href': 'https://api.spotify.com/v1/tracks/1qlMTivCjISCkR3gLAB3tc',
#     'id': '1qlMTivCjISCkR3gLAB3tc',
#     'is_local': False,
#     'name': 'A Strange Education',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1386590213bdb152a592e7e548edecb1c8197867?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1qlMTivCjISCkR3gLAB3tc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/048FBwXjFYBWxSggPDipic'},
#        'href': 'https://api.spotify.com/v1/artists/048FBwXjFYBWxSggPDipic',
#        'id': '048FBwXjFYBWxSggPDipic',
#        'name': 'Maximo Park',
#        'type': 'artist',
#        'uri': 'spotify:artist:048FBwXjFYBWxSggPDipic'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6mDHmXgvy79alh2CwEmMxJ'},
#      'href': 'https://api.spotify.com/v1/albums/6mDHmXgvy79alh2CwEmMxJ',
#      'id': '6mDHmXgvy79alh2CwEmMxJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cc446d347e881f544131f10e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cc446d347e881f544131f10e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cc446d347e881f544131f10e',
#        'width': 64}],
#      'name': 'Our Earthly Pleasures',
#      'release_date': '2007-04-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6mDHmXgvy79alh2CwEmMxJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/048FBwXjFYBWxSggPDipic'},
#       'href': 'https://api.spotify.com/v1/artists/048FBwXjFYBWxSggPDipic',
#       'id': '048FBwXjFYBWxSggPDipic',
#       'name': 'Maximo Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:048FBwXjFYBWxSggPDipic'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 208653,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBPW0600157'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7aB9V1AfdHhdONxii7njJ9'},
#     'href': 'https://api.spotify.com/v1/tracks/7aB9V1AfdHhdONxii7njJ9',
#     'id': '7aB9V1AfdHhdONxii7njJ9',
#     'is_local': False,
#     'name': 'Books From Boxes',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7aB9V1AfdHhdONxii7njJ9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/048FBwXjFYBWxSggPDipic'},
#        'href': 'https://api.spotify.com/v1/artists/048FBwXjFYBWxSggPDipic',
#        'id': '048FBwXjFYBWxSggPDipic',
#        'name': 'Maximo Park',
#        'type': 'artist',
#        'uri': 'spotify:artist:048FBwXjFYBWxSggPDipic'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6mDHmXgvy79alh2CwEmMxJ'},
#      'href': 'https://api.spotify.com/v1/albums/6mDHmXgvy79alh2CwEmMxJ',
#      'id': '6mDHmXgvy79alh2CwEmMxJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cc446d347e881f544131f10e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cc446d347e881f544131f10e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cc446d347e881f544131f10e',
#        'width': 64}],
#      'name': 'Our Earthly Pleasures',
#      'release_date': '2007-04-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6mDHmXgvy79alh2CwEmMxJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/048FBwXjFYBWxSggPDipic'},
#       'href': 'https://api.spotify.com/v1/artists/048FBwXjFYBWxSggPDipic',
#       'id': '048FBwXjFYBWxSggPDipic',
#       'name': 'Maximo Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:048FBwXjFYBWxSggPDipic'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 200386,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBPW0600156'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1yG1OpMiV8WtDeOYEBvNW8'},
#     'href': 'https://api.spotify.com/v1/tracks/1yG1OpMiV8WtDeOYEBvNW8',
#     'id': '1yG1OpMiV8WtDeOYEBvNW8',
#     'is_local': False,
#     'name': 'Our Velocity',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1yG1OpMiV8WtDeOYEBvNW8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-04-13T17:09:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/secretagentfrog'},
#     'href': 'https://api.spotify.com/v1/users/secretagentfrog',
#     'id': 'secretagentfrog',
#     'type': 'user',
#     'uri': 'spotify:user:secretagentfrog'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qlAMLpUyBjZgnzuFXXZXI'},
#        'href': 'https://api.spotify.com/v1/artists/2qlAMLpUyBjZgnzuFXXZXI',
#        'id': '2qlAMLpUyBjZgnzuFXXZXI',
#        'name': 'Klaxons',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qlAMLpUyBjZgnzuFXXZXI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'GN',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KH',
#       'KR',
#       'KW',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'ME',
#       'MK',
#       'MT',
#       'MU',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3X36TxPDnlK0Ie61NLMYwy'},
#      'href': 'https://api.spotify.com/v1/albums/3X36TxPDnlK0Ie61NLMYwy',
#      'id': '3X36TxPDnlK0Ie61NLMYwy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27317e3da86c8c96bb1f45f5b90',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0217e3da86c8c96bb1f45f5b90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485117e3da86c8c96bb1f45f5b90',
#        'width': 64}],
#      'name': 'Myths Of The Near Future (Exclusive to specific BPs)',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3X36TxPDnlK0Ie61NLMYwy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qlAMLpUyBjZgnzuFXXZXI'},
#       'href': 'https://api.spotify.com/v1/artists/2qlAMLpUyBjZgnzuFXXZXI',
#       'id': '2qlAMLpUyBjZgnzuFXXZXI',
#       'name': 'Klaxons',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qlAMLpUyBjZgnzuFXXZXI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KH',
#      'KR',
#      'KW',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 138466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM70606234'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4qSvgKOY2MgXh0lrFO6NOq'},
#     'href': 'https://api.spotify.com/v1/tracks/4qSvgKOY2MgXh0lrFO6NOq',
#     'id': '4qSvgKOY2MgXh0lrFO6NOq',
#     'is_local': False,
#     'name': 'Four Horsemen Of 2012',
#     'popularity': 7,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4qSvgKOY2MgXh0lrFO6NOq'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/5xqpyfZyS1DVysoevdVyEn/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 10991}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["items"][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
playlist["total"]
# Out:
# 10991

# %%
len(playlist["items"])
# Out:
# 100

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/5xqpyfZyS1DVysoevdVyEn/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("5xqpyfZyS1DVysoevdVyEn")
len(all_tracks)
# Out:
# 10991

# %%
tracks2 = json_normalize(all_tracks)

# %%
tracks2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2016-04-13T17:09:41Z     False          None
# 1  2016-04-13T17:09:41Z     False          None
# 2  2016-04-13T17:09:41Z     False          None
# 3  2016-04-13T17:09:41Z     False          None
# 4  2016-04-13T17:09:41Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/secretagentfrog
# 1  https://open.spotify.com/user/secretagentfrog
# 2  https://open.spotify.com/user/secretagentfrog
# 3  https://open.spotify.com/user/secretagentfrog
# 4  https://open.spotify.com/user/secretagentfrog
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 1  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 2  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 3  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 4  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:secretagentfrog                  album
# 1          user  spotify:user:secretagentfrog                 single
# 2          user  spotify:user:secretagentfrog                  album
# 3          user  spotify:user:secretagentfrog                  album
# 4          user  spotify:user:secretagentfrog                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local                track.name  \
# 0  3AA8xNhDC0MpqwkGX3EP5V          False     If I Ever Feel Better
# 1  2i8lRhmZNKaM1ypHwRybuD          False  Dance To The Underground
# 2  4flxgPC0426CEeSrzQIic0          False                 How We Do
# 3  1XHFob24QklIXtLRopKirJ          False        Fuck the Pain Away
# 4  4JB847zlgViLq8tJIzRsZy          False          Street Surgery 2
#
#   track.popularity                                  track.preview_url  \
# 0               66  https://p.scdn.co/mp3-preview/eb1e1d7972172e23...
# 1               29  https://p.scdn.co/mp3-preview/bf9953e29d806a33...
# 2               34  https://p.scdn.co/mp3-preview/7b8c0e7b8498eaf4...
# 3                0                                               None
# 4                0                                               None
#
#   track.track track.track_number track.type  \
# 0        True                  4      track
# 1        True                  1      track
# 2        True                  1      track
# 3        True                  1      track
# 4        True                  4      track
#
#                               track.uri video_thumbnail.url
# 0  spotify:track:3AA8xNhDC0MpqwkGX3EP5V                None
# 1  spotify:track:2i8lRhmZNKaM1ypHwRybuD                None
# 2  spotify:track:4flxgPC0426CEeSrzQIic0                None
# 3  spotify:track:1XHFob24QklIXtLRopKirJ                None
# 4  spotify:track:4JB847zlgViLq8tJIzRsZy                None
#
# [5 rows x 40 columns]

# %%
tracks2['track.artists']
# Out:
# 0        [{'external_urls': {'spotify': 'https://open.s...
# 1        [{'external_urls': {'spotify': 'https://open.s...
# 2        [{'external_urls': {'spotify': 'https://open.s...
# 3        [{'external_urls': {'spotify': 'https://open.s...
# 4        [{'external_urls': {'spotify': 'https://open.s...
#                                ...
# 10986    [{'external_urls': {'spotify': 'https://open.s...
# 10987    [{'external_urls': {'spotify': 'https://open.s...
# 10988    [{'external_urls': {'spotify': 'https://open.s...
# 10989    [{'external_urls': {'spotify': 'https://open.s...
# 10990    [{'external_urls': {'spotify': 'https://open.s...
# Name: track.artists, Length: 10991, dtype: object

# %%
def expand_list_dict2(row):
    df = json_normalize(row['track.artists'])
    df['song_id'] = row['track.id']
    return df

tracks2['artists_dfs'] = tracks2.apply(expand_list_dict2, axis=1)
tracks2['artists_dfs'][3]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1gkSl4XpHIH...  1gkSl4XpHIHI4I1WQbfXOE
#
#       name    type                                    uri  \
# 0  Peaches  artist  spotify:artist:1gkSl4XpHIHI4I1WQbfXOE
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/1gkSl4XpHIHI4I...  1XHFob24QklIXtLRopKirJ

# %%
# now we create a new dataframe with all these artists
artist_df2 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df in tracks2['artists_dfs']:
    #display(val)
    artist_df2 = pd.concat([artist_df2, mini_df], axis=0)
    
artist_df2
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/1xU878Z1QtB...  1xU878Z1QtBldR7ru9owdU
# 0   https://api.spotify.com/v1/artists/2oWyxHNcxMc...  2oWyxHNcxMcrvNIHMX2apR
# 0   https://api.spotify.com/v1/artists/2UyhhfLOvfL...  2UyhhfLOvfLs7ZhzsAaNC3
# 0   https://api.spotify.com/v1/artists/1gkSl4XpHIH...  1gkSl4XpHIHI4I1WQbfXOE
# 0   https://api.spotify.com/v1/artists/3GpAL7oEFD3...  3GpAL7oEFD37IJDOOiirqy
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/4HpHDJqNFP3...  4HpHDJqNFP3XsGRy0SKTq4
# 0   https://api.spotify.com/v1/artists/2sriRQRt36D...  2sriRQRt36DnfHtD68zZlj
# 0   https://api.spotify.com/v1/artists/54QMjE4toDf...  54QMjE4toDfiCryzYWCpXX
# 0   https://api.spotify.com/v1/artists/5wFXmYsg3KF...  5wFXmYsg3KFJ8BDsQudJ4f
# 0   https://api.spotify.com/v1/artists/4LdZNE5MHGq...  4LdZNE5MHGqvc0N9ivXNF3
#
#                     name    type                                    uri  \
# 0                Phoenix  artist  spotify:artist:1xU878Z1QtBldR7ru9owdU
# 0                Radio 4  artist  spotify:artist:2oWyxHNcxMcrvNIHMX2apR
# 0             Mount Sims  artist  spotify:artist:2UyhhfLOvfLs7ZhzsAaNC3
# 0                Peaches  artist  spotify:artist:1gkSl4XpHIHI4I1WQbfXOE
# 0               Zongamin  artist  spotify:artist:3GpAL7oEFD37IJDOOiirqy
# ..                   ...     ...                                    ...
# 0            SLEEP RADIO  artist  spotify:artist:4HpHDJqNFP3XsGRy0SKTq4
# 0         Dorian Concept  artist  spotify:artist:2sriRQRt36DnfHtD68zZlj
# 0              Metronomy  artist  spotify:artist:54QMjE4toDfiCryzYWCpXX
# 0   Manchester Orchestra  artist  spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f
# 0     The Joy Formidable  artist  spotify:artist:4LdZNE5MHGqvc0N9ivXNF3
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/1xU878Z1QtBldR...  3AA8xNhDC0MpqwkGX3EP5V
# 0   https://open.spotify.com/artist/2oWyxHNcxMcrvN...  2i8lRhmZNKaM1ypHwRybuD
# 0   https://open.spotify.com/artist/2UyhhfLOvfLs7Z...  4flxgPC0426CEeSrzQIic0
# 0   https://open.spotify.com/artist/1gkSl4XpHIHI4I...  1XHFob24QklIXtLRopKirJ
# 0   https://open.spotify.com/artist/3GpAL7oEFD37IJ...  4JB847zlgViLq8tJIzRsZy
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/4HpHDJqNFP3XsG...  1v6vHkDHBjm4OHUzeOKber
# 0   https://open.spotify.com/artist/2sriRQRt36DnfH...  5TN8n4LQS8Or2WEnU56pXs
# 0   https://open.spotify.com/artist/54QMjE4toDfiCr...  6MEzr1cmAJi3FXBjXVXMnm
# 0   https://open.spotify.com/artist/5wFXmYsg3KFJ8B...  6ovSjbBKatyx9KvWsxkAZo
# 0   https://open.spotify.com/artist/4LdZNE5MHGqvc0...  6CO46FIr0FSGT0h0QXjpmH
#
# [12681 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged2 = pd.merge(left=tracks2,
                    right=artist_df2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2016-04-13T17:09:41Z     False          None
# 1  2016-04-13T17:09:41Z     False          None
# 2  2016-04-13T17:09:41Z     False          None
# 3  2016-04-13T17:09:41Z     False          None
# 4  2016-04-13T17:09:41Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/secretagentfrog
# 1  https://open.spotify.com/user/secretagentfrog
# 2  https://open.spotify.com/user/secretagentfrog
# 3  https://open.spotify.com/user/secretagentfrog
# 4  https://open.spotify.com/user/secretagentfrog
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 1  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 2  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 3  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 4  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:secretagentfrog                  album
# 1          user  spotify:user:secretagentfrog                 single
# 2          user  spotify:user:secretagentfrog                  album
# 3          user  spotify:user:secretagentfrog                  album
# 4          user  spotify:user:secretagentfrog                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:3AA8xNhDC0MpqwkGX3EP5V                None
# 1  spotify:track:2i8lRhmZNKaM1ypHwRybuD                None
# 2  spotify:track:4flxgPC0426CEeSrzQIic0                None
# 3  spotify:track:1XHFob24QklIXtLRopKirJ                None
# 4  spotify:track:4JB847zlgViLq8tJIzRsZy                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1xU878Z1QtB...  1xU878Z1QtBldR7ru9owdU
# 1  https://api.spotify.com/v1/artists/2oWyxHNcxMc...  2oWyxHNcxMcrvNIHMX2apR
# 2  https://api.spotify.com/v1/artists/2UyhhfLOvfL...  2UyhhfLOvfLs7ZhzsAaNC3
# 3  https://api.spotify.com/v1/artists/1gkSl4XpHIH...  1gkSl4XpHIHI4I1WQbfXOE
# 4  https://api.spotify.com/v1/artists/3GpAL7oEFD3...  3GpAL7oEFD37IJDOOiirqy
#
#          name    type                                    uri  \
# 0     Phoenix  artist  spotify:artist:1xU878Z1QtBldR7ru9owdU
# 1     Radio 4  artist  spotify:artist:2oWyxHNcxMcrvNIHMX2apR
# 2  Mount Sims  artist  spotify:artist:2UyhhfLOvfLs7ZhzsAaNC3
# 3     Peaches  artist  spotify:artist:1gkSl4XpHIHI4I1WQbfXOE
# 4    Zongamin  artist  spotify:artist:3GpAL7oEFD37IJDOOiirqy
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/1xU878Z1QtBldR...  3AA8xNhDC0MpqwkGX3EP5V
# 1  https://open.spotify.com/artist/2oWyxHNcxMcrvN...  2i8lRhmZNKaM1ypHwRybuD
# 2  https://open.spotify.com/artist/2UyhhfLOvfLs7Z...  4flxgPC0426CEeSrzQIic0
# 3  https://open.spotify.com/artist/1gkSl4XpHIHI4I...  1XHFob24QklIXtLRopKirJ
# 4  https://open.spotify.com/artist/3GpAL7oEFD37IJ...  4JB847zlgViLq8tJIzRsZy
#
# [5 rows x 48 columns]

# %%
df_final2 = df_merged2[['track.name', 'name', 'song_id']]
df_final2
# Out:
#                         track.name                  name  \
# 0            If I Ever Feel Better               Phoenix
# 1         Dance To The Underground               Radio 4
# 2                        How We Do            Mount Sims
# 3               Fuck the Pain Away               Peaches
# 4                 Street Surgery 2              Zongamin
# ...                            ...                   ...
# 12676  Hate Is an Attractive Force           SLEEP RADIO
# 12677                     Promises        Dorian Concept
# 12678                      16 Beat             Metronomy
# 12679     Amplified In The Silence  Manchester Orchestra
# 12680               The Wrong Side    The Joy Formidable
#
#                       song_id
# 0      3AA8xNhDC0MpqwkGX3EP5V
# 1      2i8lRhmZNKaM1ypHwRybuD
# 2      4flxgPC0426CEeSrzQIic0
# 3      1XHFob24QklIXtLRopKirJ
# 4      4JB847zlgViLq8tJIzRsZy
# ...                       ...
# 12676  1v6vHkDHBjm4OHUzeOKber
# 12677  5TN8n4LQS8Or2WEnU56pXs
# 12678  6MEzr1cmAJi3FXBjXVXMnm
# 12679  6ovSjbBKatyx9KvWsxkAZo
# 12680  6CO46FIr0FSGT0h0QXjpmH
#
# [12681 rows x 3 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final2), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final2['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 12681

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True) # duplicates because some songs have more artists

# %%
df_w_audio_ft = pd.merge(left=df_final2,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                         track.name                  name  \
# 0            If I Ever Feel Better               Phoenix
# 1         Dance To The Underground               Radio 4
# 2                        How We Do            Mount Sims
# 3               Fuck the Pain Away               Peaches
# 4                 Street Surgery 2              Zongamin
# ...                            ...                   ...
# 12676  Hate Is an Attractive Force           SLEEP RADIO
# 12677                     Promises        Dorian Concept
# 12678                      16 Beat             Metronomy
# 12679     Amplified In The Silence  Manchester Orchestra
# 12680               The Wrong Side    The Joy Formidable
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      3AA8xNhDC0MpqwkGX3EP5V         0.755   0.553    6    -9.449     0
# 1      2i8lRhmZNKaM1ypHwRybuD         0.667   0.667    7    -6.267     1
# 2      4flxgPC0426CEeSrzQIic0         0.826   0.601   10    -3.966     0
# 3      1XHFob24QklIXtLRopKirJ         0.905   0.945    4    -2.630     1
# 4      4JB847zlgViLq8tJIzRsZy         0.797   0.536   11    -8.267     0
# ...                       ...           ...     ...  ...       ...   ...
# 12676  1v6vHkDHBjm4OHUzeOKber         0.759   0.121    7   -25.346     0
# 12677  5TN8n4LQS8Or2WEnU56pXs         0.621   0.675   10    -9.347     0
# 12678  6MEzr1cmAJi3FXBjXVXMnm         0.781   0.812    7   -11.866     1
# 12679  6ovSjbBKatyx9KvWsxkAZo         0.557   0.117    1   -13.880     1
# 12680  6CO46FIr0FSGT0h0QXjpmH         0.426   0.746    0    -3.555     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.1070       0.04920  ...    0.0646    0.836  119.700
# 1           0.0388       0.00013  ...    0.0711    0.843  130.321
# 2           0.0515       0.19500  ...    0.0700    0.948  126.971
# 3           0.1370       0.03540  ...    0.0707    0.944  131.597
# 4           0.2660       0.03150  ...    0.1700    0.704  102.881
# ...            ...           ...  ...       ...      ...      ...
# 12676       0.0284       0.41000  ...    0.0905    0.523   90.029
# 12677       0.0685       0.38500  ...    0.3470    0.323  124.056
# 12678       0.0468       0.01860  ...    0.0716    0.785  115.001
# 12679       0.0344       0.95000  ...    0.1120    0.122  111.742
# 12680       0.0725       0.07950  ...    0.0595    0.433  149.985
#
#                  type                      id  \
# 0      audio_features  3AA8xNhDC0MpqwkGX3EP5V
# 1      audio_features  2i8lRhmZNKaM1ypHwRybuD
# 2      audio_features  4flxgPC0426CEeSrzQIic0
# 3      audio_features  1XHFob24QklIXtLRopKirJ
# 4      audio_features  4JB847zlgViLq8tJIzRsZy
# ...               ...                     ...
# 12676  audio_features  1v6vHkDHBjm4OHUzeOKber
# 12677  audio_features  5TN8n4LQS8Or2WEnU56pXs
# 12678  audio_features  6MEzr1cmAJi3FXBjXVXMnm
# 12679  audio_features  6ovSjbBKatyx9KvWsxkAZo
# 12680  audio_features  6CO46FIr0FSGT0h0QXjpmH
#
#                                         uri  \
# 0      spotify:track:3AA8xNhDC0MpqwkGX3EP5V
# 1      spotify:track:2i8lRhmZNKaM1ypHwRybuD
# 2      spotify:track:4flxgPC0426CEeSrzQIic0
# 3      spotify:track:1XHFob24QklIXtLRopKirJ
# 4      spotify:track:4JB847zlgViLq8tJIzRsZy
# ...                                     ...
# 12676  spotify:track:1v6vHkDHBjm4OHUzeOKber
# 12677  spotify:track:5TN8n4LQS8Or2WEnU56pXs
# 12678  spotify:track:6MEzr1cmAJi3FXBjXVXMnm
# 12679  spotify:track:6ovSjbBKatyx9KvWsxkAZo
# 12680  spotify:track:6CO46FIr0FSGT0h0QXjpmH
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3AA8xNhDC0Mp...
# 1      https://api.spotify.com/v1/tracks/2i8lRhmZNKaM...
# 2      https://api.spotify.com/v1/tracks/4flxgPC0426C...
# 3      https://api.spotify.com/v1/tracks/1XHFob24QklI...
# 4      https://api.spotify.com/v1/tracks/4JB847zlgViL...
# ...                                                  ...
# 12676  https://api.spotify.com/v1/tracks/1v6vHkDHBjm4...
# 12677  https://api.spotify.com/v1/tracks/5TN8n4LQS8Or...
# 12678  https://api.spotify.com/v1/tracks/6MEzr1cmAJi3...
# 12679  https://api.spotify.com/v1/tracks/6ovSjbBKatyx...
# 12680  https://api.spotify.com/v1/tracks/6CO46FIr0FSG...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3AA8...      266600
# 1      https://api.spotify.com/v1/audio-analysis/2i8l...      243213
# 2      https://api.spotify.com/v1/audio-analysis/4flx...      234000
# 3      https://api.spotify.com/v1/audio-analysis/1XHF...      250693
# 4      https://api.spotify.com/v1/audio-analysis/4JB8...      224800
# ...                                                  ...         ...
# 12676  https://api.spotify.com/v1/audio-analysis/1v6v...      170667
# 12677  https://api.spotify.com/v1/audio-analysis/5TN8...      237064
# 12678  https://api.spotify.com/v1/audio-analysis/6MEz...      196027
# 12679  https://api.spotify.com/v1/audio-analysis/6ovS...      223107
# 12680  https://api.spotify.com/v1/audio-analysis/6CO4...      214600
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 12676               4
# 12677               1
# 12678               4
# 12679               4
# 12680               3
#
# [12681 rows x 21 columns]

# %% [markdown]
# # Segunda playlist

# %%
playlist2 = sp.user_playlist_tracks("spotify", "5S8SJdl1BDc0ugpkEvFsIL")

# %%
playlist2
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5S8SJdl1BDc0ugpkEvFsIL/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2017-11-20T02:52:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0HG8fMDhvN2tH5uPHFsyZP'},
#      'href': 'https://api.spotify.com/v1/albums/0HG8fMDhvN2tH5uPHFsyZP',
#      'id': '0HG8fMDhvN2tH5uPHFsyZP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734322e9bd7d57d061d0e19e1f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024322e9bd7d57d061d0e19e1f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514322e9bd7d57d061d0e19e1f',
#        'width': 64}],
#      'name': '...Ready For It?',
#      'release_date': '2017-09-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0HG8fMDhvN2tH5uPHFsyZP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 208198,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCJY1750003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7zgqtptZvhf8GEmdsM2vp2'},
#     'href': 'https://api.spotify.com/v1/tracks/7zgqtptZvhf8GEmdsM2vp2',
#     'id': '7zgqtptZvhf8GEmdsM2vp2',
#     'is_local': False,
#     'name': '...Ready For It?',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7zgqtptZvhf8GEmdsM2vp2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-20T02:42:15Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6x2LnllRG5uGarZMsD4iO8'},
#        'href': 'https://api.spotify.com/v1/artists/6x2LnllRG5uGarZMsD4iO8',
#        'id': '6x2LnllRG5uGarZMsD4iO8',
#        'name': 'Thomas Rhett',
#        'type': 'artist',
#        'uri': 'spotify:artist:6x2LnllRG5uGarZMsD4iO8'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4w5Jvreahp3yvLqc4vCr9I'},
#      'href': 'https://api.spotify.com/v1/albums/4w5Jvreahp3yvLqc4vCr9I',
#      'id': '4w5Jvreahp3yvLqc4vCr9I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a005bf5c526a44272ef20c79',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a005bf5c526a44272ef20c79',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a005bf5c526a44272ef20c79',
#        'width': 64}],
#      'name': 'Life Changes',
#      'release_date': '2017-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4w5Jvreahp3yvLqc4vCr9I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6x2LnllRG5uGarZMsD4iO8'},
#       'href': 'https://api.spotify.com/v1/artists/6x2LnllRG5uGarZMsD4iO8',
#       'id': '6x2LnllRG5uGarZMsD4iO8',
#       'name': 'Thomas Rhett',
#       'type': 'artist',
#       'uri': 'spotify:artist:6x2LnllRG5uGarZMsD4iO8'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 190226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLXJ1707376'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Vxu50qVrQcycjRyJQaZLC'},
#     'href': 'https://api.spotify.com/v1/tracks/4Vxu50qVrQcycjRyJQaZLC',
#     'id': '4Vxu50qVrQcycjRyJQaZLC',
#     'is_local': False,
#     'name': 'Life Changes',
#     'popularity': 62,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4Vxu50qVrQcycjRyJQaZLC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-20T02:36:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PgleR09JVnm3zY1fW3XBA'},
#      'href': 'https://api.spotify.com/v1/albums/4PgleR09JVnm3zY1fW3XBA',
#      'id': '4PgleR09JVnm3zY1fW3XBA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273232711f7d66a1e19e89e28c5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02232711f7d66a1e19e89e28c5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851232711f7d66a1e19e89e28c5',
#        'width': 64}],
#      'name': '24K Magic',
#      'release_date': '2016-11-17',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4PgleR09JVnm3zY1fW3XBA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 225983,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21602944'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6b8Be6ljOzmkOmFslEb23P'},
#     'href': 'https://api.spotify.com/v1/tracks/6b8Be6ljOzmkOmFslEb23P',
#     'id': '6b8Be6ljOzmkOmFslEb23P',
#     'is_local': False,
#     'name': '24K Magic',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3a76820d510fa5f84abb413e9d13815bcc86da0f?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6b8Be6ljOzmkOmFslEb23P'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-12-06T01:26:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 170826,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700026'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0afhq8XCExXpqazXczTSve'},
#     'href': 'https://api.spotify.com/v1/tracks/0afhq8XCExXpqazXczTSve',
#     'id': '0afhq8XCExXpqazXczTSve',
#     'is_local': False,
#     'name': 'Galway Girl',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9b7635464dc2caea3837fcc5680d0f5f5d39ab03?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0afhq8XCExXpqazXczTSve'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-20T02:36:14Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'HT',
#       'JM',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'FM',
#       'NA',
#       'NE',
#       'PG',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'KN',
#       'LC',
#       'VC',
#       'TL',
#       'TT',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#      'href': 'https://api.spotify.com/v1/albums/1xn54DMo2qIqBuMqHtUsFd',
#      'id': '1xn54DMo2qIqBuMqHtUsFd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313b3e37318a0c247b550bccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213b3e37318a0c247b550bccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113b3e37318a0c247b550bccd',
#        'width': 64}],
#      'name': 'x (Deluxe Edition)',
#      'release_date': '2014-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:1xn54DMo2qIqBuMqHtUsFd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 258986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1400094'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HNkqx9Ahdgi1Ixy2xkKkL'},
#     'href': 'https://api.spotify.com/v1/tracks/1HNkqx9Ahdgi1Ixy2xkKkL',
#     'id': '1HNkqx9Ahdgi1Ixy2xkKkL',
#     'is_local': False,
#     'name': 'Photograph',
#     'popularity': 87,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d90f4e5f15d8ed411307945560b1db8cca6b253b?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-20T02:37:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#        'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#        'id': '4nDoRrQiYLoBzwC5BhVJzF',
#        'name': 'Camila Cabello',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5chBPOVY2I0bG5V3igb5QL'},
#      'href': 'https://api.spotify.com/v1/albums/5chBPOVY2I0bG5V3igb5QL',
#      'id': '5chBPOVY2I0bG5V3igb5QL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d93cf4d07ba50d7b32ca7c44',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d93cf4d07ba50d7b32ca7c44',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d93cf4d07ba50d7b32ca7c44',
#        'width': 64}],
#      'name': 'Havana (feat. Young Thug)',
#      'release_date': '2017-08-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5chBPOVY2I0bG5V3igb5QL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#       'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#       'id': '4nDoRrQiYLoBzwC5BhVJzF',
#       'name': 'Camila Cabello',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#       'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#       'id': '50co4Is1HCEo8bhOyUWKpn',
#       'name': 'Young Thug',
#       'type': 'artist',
#       'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 216896,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11706905'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ofbQMrRDsUaVKq2mGLEAb'},
#     'href': 'https://api.spotify.com/v1/tracks/0ofbQMrRDsUaVKq2mGLEAb',
#     'id': '0ofbQMrRDsUaVKq2mGLEAb',
#     'is_local': False,
#     'name': 'Havana (feat. Young Thug)',
#     'popularity': 2,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ofbQMrRDsUaVKq2mGLEAb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-21T20:17:08Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'LI',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'HT',
#       'JM',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'FM',
#       'NA',
#       'NE',
#       'PG',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'KN',
#       'LC',
#       'VC',
#       'TL',
#       'TT',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/58ufpQsJ1DS5kq4hhzQDiI'},
#      'href': 'https://api.spotify.com/v1/albums/58ufpQsJ1DS5kq4hhzQDiI',
#      'id': '58ufpQsJ1DS5kq4hhzQDiI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273926f43e7cce571e62720fd46',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02926f43e7cce571e62720fd46',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851926f43e7cce571e62720fd46',
#        'width': 64}],
#      'name': 'Unorthodox Jukebox',
#      'release_date': '2012-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:58ufpQsJ1DS5kq4hhzQDiI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'LI',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 213826,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21206701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0nJW01T7XtvILxQgC5J7Wh'},
#     'href': 'https://api.spotify.com/v1/tracks/0nJW01T7XtvILxQgC5J7Wh',
#     'id': '0nJW01T7XtvILxQgC5J7Wh',
#     'is_local': False,
#     'name': 'When I Was Your Man',
#     'popularity': 89,
#     'preview_url': 'https://p.scdn.co/mp3-preview/159fc05584217baa99581c4821f52d04670db6b2?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0nJW01T7XtvILxQgC5J7Wh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-20T18:48:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1DqgNIlDZPscRHgdCgDhZR'},
#      'href': 'https://api.spotify.com/v1/albums/1DqgNIlDZPscRHgdCgDhZR',
#      'id': '1DqgNIlDZPscRHgdCgDhZR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273559769036607549f92579d08',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02559769036607549f92579d08',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851559769036607549f92579d08',
#        'width': 64}],
#      'name': 'Rocky III: Music From The Motion Picture',
#      'release_date': '1982-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1DqgNIlDZPscRHgdCgDhZR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/272ygo5fv9cYsiCLcV0HV2'},
#       'href': 'https://api.spotify.com/v1/artists/272ygo5fv9cYsiCLcV0HV2',
#       'id': '272ygo5fv9cYsiCLcV0HV2',
#       'name': 'Bill Conti',
#       'type': 'artist',
#       'uri': 'spotify:artist:272ygo5fv9cYsiCLcV0HV2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 170240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNPD0500346'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6C2PfemHQul77DVpnvuAIs'},
#     'href': 'https://api.spotify.com/v1/tracks/6C2PfemHQul77DVpnvuAIs',
#     'id': '6C2PfemHQul77DVpnvuAIs',
#     'is_local': False,
#     'name': 'Gonna Fly Now',
#     'popularity': 57,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6C2PfemHQul77DVpnvuAIs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-27T21:45:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#        'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#        'id': '04gDigrS5kc9YWfZHwBETP',
#        'name': 'Maroon 5',
#        'type': 'artist',
#        'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1qvLKCq4Xh355Fq0VswCpH'},
#      'href': 'https://api.spotify.com/v1/albums/1qvLKCq4Xh355Fq0VswCpH',
#      'id': '1qvLKCq4Xh355Fq0VswCpH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d87fe4a7e157a1ecb7566ef5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d87fe4a7e157a1ecb7566ef5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d87fe4a7e157a1ecb7566ef5',
#        'width': 64}],
#      'name': 'Red Pill Blues (Deluxe)',
#      'release_date': '2017-11-03',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1qvLKCq4Xh355Fq0VswCpH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/04gDigrS5kc9YWfZHwBETP'},
#       'href': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP',
#       'id': '04gDigrS5kc9YWfZHwBETP',
#       'name': 'Maroon 5',
#       'type': 'artist',
#       'uri': 'spotify:artist:04gDigrS5kc9YWfZHwBETP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 214265,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71609975'},
# ...
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71003721'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1DqdF42leyFIzqNDv9CjId'},
#     'href': 'https://api.spotify.com/v1/tracks/1DqdF42leyFIzqNDv9CjId',
#     'id': '1DqdF42leyFIzqNDv9CjId',
#     'is_local': False,
#     'name': 'Dynamite',
#     'popularity': 73,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1DqdF42leyFIzqNDv9CjId'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-21T19:41:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/36fdxiOzdlmsrHgGcfvqUJ'},
#      'href': 'https://api.spotify.com/v1/albums/36fdxiOzdlmsrHgGcfvqUJ',
#      'id': '36fdxiOzdlmsrHgGcfvqUJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f051a314bb7eaa973c795176',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f051a314bb7eaa973c795176',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f051a314bb7eaa973c795176',
#        'width': 64}],
#      'name': 'THE E.N.D. (THE ENERGY NEVER DIES)',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:36fdxiOzdlmsrHgGcfvqUJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 289133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70965169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4vp2J1l5RD4gMZwGFLfRAu'},
#     'href': 'https://api.spotify.com/v1/tracks/4vp2J1l5RD4gMZwGFLfRAu',
#     'id': '4vp2J1l5RD4gMZwGFLfRAu',
#     'is_local': False,
#     'name': 'I Gotta Feeling',
#     'popularity': 2,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4vp2J1l5RD4gMZwGFLfRAu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-21T19:45:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nCi3BB41mBaMH9gfr6Su0'},
#        'href': 'https://api.spotify.com/v1/artists/5nCi3BB41mBaMH9gfr6Su0',
#        'id': '5nCi3BB41mBaMH9gfr6Su0',
#        'name': 'fun.',
#        'type': 'artist',
#        'uri': 'spotify:artist:5nCi3BB41mBaMH9gfr6Su0'}],
#      'available_markets': ['AR',
#       'AU',
#       'BE',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'DK',
#       'DO',
#       'EC',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'IS',
#       'IE',
#       'IT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PT',
#       'SG',
#       'ES',
#       'SE',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'HT',
#       'JM',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'FM',
#       'NA',
#       'NE',
#       'PG',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'KN',
#       'LC',
#       'VC',
#       'TL',
#       'TT',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7m7F7SQ3BXvIpvOgjW51Gp'},
#      'href': 'https://api.spotify.com/v1/albums/7m7F7SQ3BXvIpvOgjW51Gp',
#      'id': '7m7F7SQ3BXvIpvOgjW51Gp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a036e1724bc7f2bab15cfda8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a036e1724bc7f2bab15cfda8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a036e1724bc7f2bab15cfda8',
#        'width': 64}],
#      'name': 'Some Nights',
#      'release_date': '2012-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7m7F7SQ3BXvIpvOgjW51Gp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nCi3BB41mBaMH9gfr6Su0'},
#       'href': 'https://api.spotify.com/v1/artists/5nCi3BB41mBaMH9gfr6Su0',
#       'id': '5nCi3BB41mBaMH9gfr6Su0',
#       'name': 'fun.',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nCi3BB41mBaMH9gfr6Su0'}],
#     'available_markets': ['AR',
#      'AU',
#      'BE',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'DK',
#      'DO',
#      'EC',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'IS',
#      'IE',
#      'IT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PT',
#      'SG',
#      'ES',
#      'SE',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 277040,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21104050'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/67WTwafOMgegV6ABnBQxcE'},
#     'href': 'https://api.spotify.com/v1/tracks/67WTwafOMgegV6ABnBQxcE',
#     'id': '67WTwafOMgegV6ABnBQxcE',
#     'is_local': False,
#     'name': 'Some Nights',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/270d1a141e0493689e31d43c42b464e23583b820?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:67WTwafOMgegV6ABnBQxcE'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-11-21T19:45:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/twgeb7mzdcv4u8h191dxrvlpc'},
#     'href': 'https://api.spotify.com/v1/users/twgeb7mzdcv4u8h191dxrvlpc',
#     'id': 'twgeb7mzdcv4u8h191dxrvlpc',
#     'type': 'user',
#     'uri': 'spotify:user:twgeb7mzdcv4u8h191dxrvlpc'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TqIPD4IS1w4e30R38B3vj'},
#        'href': 'https://api.spotify.com/v1/artists/0TqIPD4IS1w4e30R38B3vj',
#        'id': '0TqIPD4IS1w4e30R38B3vj',
#        'name': 'Rupert Holmes',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TqIPD4IS1w4e30R38B3vj'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/163iYwl7Kdm9ayTnD4VyfN'},
#      'href': 'https://api.spotify.com/v1/albums/163iYwl7Kdm9ayTnD4VyfN',
#      'id': '163iYwl7Kdm9ayTnD4VyfN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273af7afb5c49afd3133fa2a6c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02af7afb5c49afd3133fa2a6c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851af7afb5c49afd3133fa2a6c9',
#        'width': 64}],
#      'name': 'Partners In Crime',
#      'release_date': '1979-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:163iYwl7Kdm9ayTnD4VyfN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TqIPD4IS1w4e30R38B3vj'},
#       'href': 'https://api.spotify.com/v1/artists/0TqIPD4IS1w4e30R38B3vj',
#       'id': '0TqIPD4IS1w4e30R38B3vj',
#       'name': 'Rupert Holmes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TqIPD4IS1w4e30R38B3vj'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 276493,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC17948997'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IMtdHjJ1OtkxbGe4zfUxQ'},
#     'href': 'https://api.spotify.com/v1/tracks/5IMtdHjJ1OtkxbGe4zfUxQ',
#     'id': '5IMtdHjJ1OtkxbGe4zfUxQ',
#     'is_local': False,
#     'name': 'Escape (The Pina Colada Song)',
#     'popularity': 77,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5IMtdHjJ1OtkxbGe4zfUxQ'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/5S8SJdl1BDc0ugpkEvFsIL/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 10000}

# %%
playlist2.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist2["total"]
# Out:
# 10000

# %%
len(playlist2["items"])
# Out:
# 100

# %%
playlist2['next']
# Out:
# 'https://api.spotify.com/v1/playlists/5S8SJdl1BDc0ugpkEvFsIL/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks2 = get_playlist_tracks("5S8SJdl1BDc0ugpkEvFsIL")
len(all_tracks2)
# Out:
# 10000

# %%
tracks21 = json_normalize(all_tracks2)

# %%
tracks21.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-11-20T02:52:18Z     False          None
# 1  2017-11-20T02:42:15Z     False          None
# 2  2017-11-20T02:36:40Z     False          None
# 3  2017-12-06T01:26:36Z     False          None
# 4  2017-11-20T02:36:14Z     False          None
#
#                       added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 1  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 2  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 3  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 4  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
#
#                                        added_by.href  \
# 0  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 1  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 2  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 3  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 4  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
#
#                  added_by.id added_by.type  \
# 0  twgeb7mzdcv4u8h191dxrvlpc          user
# 1  twgeb7mzdcv4u8h191dxrvlpc          user
# 2  twgeb7mzdcv4u8h191dxrvlpc          user
# 3  twgeb7mzdcv4u8h191dxrvlpc          user
# 4  twgeb7mzdcv4u8h191dxrvlpc          user
#
#                              added_by.uri track.album.album_type  \
# 0  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                 single
# 1  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 2  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 3  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 4  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local        track.name track.popularity  \
# 0  7zgqtptZvhf8GEmdsM2vp2          False  ...Ready For It?                0
# 1  4Vxu50qVrQcycjRyJQaZLC          False      Life Changes               62
# 2  6b8Be6ljOzmkOmFslEb23P          False         24K Magic               82
# 3  0afhq8XCExXpqazXczTSve          False       Galway Girl               81
# 4  1HNkqx9Ahdgi1Ixy2xkKkL          False        Photograph               87
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1                                               None        True
# 2  https://p.scdn.co/mp3-preview/3a76820d510fa5f8...        True
# 3  https://p.scdn.co/mp3-preview/9b7635464dc2caea...        True
# 4  https://p.scdn.co/mp3-preview/d90f4e5f15d8ed41...        True
#
#   track.track_number track.type                             track.uri  \
# 0                  1      track  spotify:track:7zgqtptZvhf8GEmdsM2vp2
# 1                  8      track  spotify:track:4Vxu50qVrQcycjRyJQaZLC
# 2                  1      track  spotify:track:6b8Be6ljOzmkOmFslEb23P
# 3                  6      track  spotify:track:0afhq8XCExXpqazXczTSve
# 4                  6      track  spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
# we can even create a new column containing these DataFrames! KEEP song URI
# NOTE: need to change this function, since the columns names are now a bit different
def expand_list_dict2(row):
    df2 = json_normalize(row['track.artists'])
    df2['song_id'] = row['track.id']
    return df2

tracks21['artists_dfs'] = tracks21.apply(expand_list_dict2, axis=1)
tracks21['artists_dfs'][3]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6eUKZXaKkcv...  6eUKZXaKkcviH0Ku9w2n3V
#
#          name    type                                    uri  \
# 0  Ed Sheeran  artist  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/6eUKZXaKkcviH0...  0afhq8XCExXpqazXczTSve

# %%
# now we create a new dataframe with all these artists
artist_df21 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df2 in tracks21['artists_dfs']:
    #display(val)
    artist_df21 = pd.concat([artist_df21, mini_df2], axis=0)
    
artist_df21
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 0   https://api.spotify.com/v1/artists/6x2LnllRG5u...  6x2LnllRG5uGarZMsD4iO8
# 0   https://api.spotify.com/v1/artists/0du5cEVh5yT...  0du5cEVh5yTK9QJze8zA0C
# 0   https://api.spotify.com/v1/artists/6eUKZXaKkcv...  6eUKZXaKkcviH0Ku9w2n3V
# 0   https://api.spotify.com/v1/artists/6eUKZXaKkcv...  6eUKZXaKkcviH0Ku9w2n3V
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/3JsMj0DEzyW...  3JsMj0DEzyWc0VDlHuy9Bx
# 0   https://api.spotify.com/v1/artists/7AC976RDJzL...  7AC976RDJzL2asmZuz7qil
# 0   https://api.spotify.com/v1/artists/4STHEaNw4mP...  4STHEaNw4mPZ2tzheohgXB
# 1   https://api.spotify.com/v1/artists/3sFhA6G1N0g...  3sFhA6G1N0gG1pszb6kk1m
# 0   https://api.spotify.com/v1/artists/0C0XlULifJt...  0C0XlULifJtAgn6ZNCW2eu
#
#               name    type                                    uri  \
# 0     Taylor Swift  artist  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 0     Thomas Rhett  artist  spotify:artist:6x2LnllRG5uGarZMsD4iO8
# 0       Bruno Mars  artist  spotify:artist:0du5cEVh5yTK9QJze8zA0C
# 0       Ed Sheeran  artist  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# 0       Ed Sheeran  artist  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# ..             ...     ...                                    ...
# 0       Supertramp  artist  spotify:artist:3JsMj0DEzyWc0VDlHuy9Bx
# 0              Yes  artist  spotify:artist:7AC976RDJzL2asmZuz7qil
# 0   Paul McCartney  artist  spotify:artist:4STHEaNw4mPZ2tzheohgXB
# 1            Wings  artist  spotify:artist:3sFhA6G1N0gG1pszb6kk1m
# 0      The Killers  artist  spotify:artist:0C0XlULifJtAgn6ZNCW2eu
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/06HL4z0CvFAxyc...  7zgqtptZvhf8GEmdsM2vp2
# 0   https://open.spotify.com/artist/6x2LnllRG5uGar...  4Vxu50qVrQcycjRyJQaZLC
# 0   https://open.spotify.com/artist/0du5cEVh5yTK9Q...  6b8Be6ljOzmkOmFslEb23P
# 0   https://open.spotify.com/artist/6eUKZXaKkcviH0...  0afhq8XCExXpqazXczTSve
# 0   https://open.spotify.com/artist/6eUKZXaKkcviH0...  1HNkqx9Ahdgi1Ixy2xkKkL
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/3JsMj0DEzyWc0V...  5pSSEkT0963muzzIjsVkrs
# 0   https://open.spotify.com/artist/7AC976RDJzL2as...  7gC6Rbllqf1yXNC02e5jz2
# 0   https://open.spotify.com/artist/4STHEaNw4mPZ2t...  6Ff77WXC58MkhLE5A1qgY1
# 1   https://open.spotify.com/artist/3sFhA6G1N0gG1p...  6Ff77WXC58MkhLE5A1qgY1
# 0   https://open.spotify.com/artist/0C0XlULifJtAgn...  1is5wwajEk2JW7Nsd63r3m
#
# [12184 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged21 = pd.merge(left=tracks21,
                    right=artist_df21,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged21.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-11-20T02:52:18Z     False          None
# 1  2017-11-20T02:42:15Z     False          None
# 2  2017-11-20T02:36:40Z     False          None
# 3  2017-12-06T01:26:36Z     False          None
# 4  2017-11-20T02:36:14Z     False          None
#
#                       added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 1  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 2  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 3  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 4  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
#
#                                        added_by.href  \
# 0  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 1  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 2  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 3  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 4  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
#
#                  added_by.id added_by.type  \
# 0  twgeb7mzdcv4u8h191dxrvlpc          user
# 1  twgeb7mzdcv4u8h191dxrvlpc          user
# 2  twgeb7mzdcv4u8h191dxrvlpc          user
# 3  twgeb7mzdcv4u8h191dxrvlpc          user
# 4  twgeb7mzdcv4u8h191dxrvlpc          user
#
#                              added_by.uri track.album.album_type  \
# 0  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                 single
# 1  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 2  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 3  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 4  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:7zgqtptZvhf8GEmdsM2vp2                None
# 1  spotify:track:4Vxu50qVrQcycjRyJQaZLC                None
# 2  spotify:track:6b8Be6ljOzmkOmFslEb23P                None
# 3  spotify:track:0afhq8XCExXpqazXczTSve                None
# 4  spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 1  https://api.spotify.com/v1/artists/6x2LnllRG5u...  6x2LnllRG5uGarZMsD4iO8
# 2  https://api.spotify.com/v1/artists/0du5cEVh5yT...  0du5cEVh5yTK9QJze8zA0C
# 3  https://api.spotify.com/v1/artists/6eUKZXaKkcv...  6eUKZXaKkcviH0Ku9w2n3V
# 4  https://api.spotify.com/v1/artists/6eUKZXaKkcv...  6eUKZXaKkcviH0Ku9w2n3V
#
#            name    type                                    uri  \
# 0  Taylor Swift  artist  spotify:artist:06HL4z0CvFAxyc27GXpf02
# 1  Thomas Rhett  artist  spotify:artist:6x2LnllRG5uGarZMsD4iO8
# 2    Bruno Mars  artist  spotify:artist:0du5cEVh5yTK9QJze8zA0C
# 3    Ed Sheeran  artist  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# 4    Ed Sheeran  artist  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/06HL4z0CvFAxyc...  7zgqtptZvhf8GEmdsM2vp2
# 1  https://open.spotify.com/artist/6x2LnllRG5uGar...  4Vxu50qVrQcycjRyJQaZLC
# 2  https://open.spotify.com/artist/0du5cEVh5yTK9Q...  6b8Be6ljOzmkOmFslEb23P
# 3  https://open.spotify.com/artist/6eUKZXaKkcviH0...  0afhq8XCExXpqazXczTSve
# 4  https://open.spotify.com/artist/6eUKZXaKkcviH0...  1HNkqx9Ahdgi1Ixy2xkKkL
#
# [5 rows x 48 columns]

# %%
df_final21 = df_merged21[['track.name', 'name', 'song_id']]
df_final21
# Out:
#                                               track.name            name  \
# 0                                       ...Ready For It?    Taylor Swift
# 1                                           Life Changes    Thomas Rhett
# 2                                              24K Magic      Bruno Mars
# 3                                            Galway Girl      Ed Sheeran
# 4                                             Photograph      Ed Sheeran
# ...                                                  ...             ...
# 12609                                    Fool's Overture      Supertramp
# 12610               Heart of the Sunrise - 2003 Remaster             Yes
# 12611  Venus And Mars / Rock Show / Jet - Live / Rema...  Paul McCartney
# 12612  Venus And Mars / Rock Show / Jet - Live / Rema...           Wings
# 12613                                     Mr. Brightside     The Killers
#
#                       song_id
# 0      7zgqtptZvhf8GEmdsM2vp2
# 1      4Vxu50qVrQcycjRyJQaZLC
# 2      6b8Be6ljOzmkOmFslEb23P
# 3      0afhq8XCExXpqazXczTSve
# 4      1HNkqx9Ahdgi1Ixy2xkKkL
# ...                       ...
# 12609  5pSSEkT0963muzzIjsVkrs
# 12610  7gC6Rbllqf1yXNC02e5jz2
# 12611  6Ff77WXC58MkhLE5A1qgY1
# 12612  6Ff77WXC58MkhLE5A1qgY1
# 12613  1is5wwajEk2JW7Nsd63r3m
#
# [12614 rows x 3 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final21), 100)]
chunks
audio_features_list1 = []
for chunk in chunks:
    df_final21['song_id'] = df_final21['song_id'].astype(str)
    id2_list100 = df_final21['song_id'][chunk[0]:chunk[1]]
    audio_features_list1 = audio_features_list1 + sp.audio_features(id2_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list1)
# Out:
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/2570961420.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final21['song_id'] = df_final21['song_id'].astype(str)
# 12614

# %%
audio_features_df1 = json_normalize(audio_features_list1)

# %%
audio_features_df1.drop_duplicates(inplace=True) # duplicates because some songs have more artists

# %%
df_w_audio_ft1 = pd.merge(left=df_final21,
                        right=audio_features_df1,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft1
# Out:
#                                               track.name            name  \
# 0                                       ...Ready For It?    Taylor Swift
# 1                                           Life Changes    Thomas Rhett
# 2                                              24K Magic      Bruno Mars
# 3                                            Galway Girl      Ed Sheeran
# 4                                             Photograph      Ed Sheeran
# ...                                                  ...             ...
# 12180                                    Fool's Overture      Supertramp
# 12181               Heart of the Sunrise - 2003 Remaster             Yes
# 12182  Venus And Mars / Rock Show / Jet - Live / Rema...  Paul McCartney
# 12183  Venus And Mars / Rock Show / Jet - Live / Rema...           Wings
# 12184                                     Mr. Brightside     The Killers
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      7zgqtptZvhf8GEmdsM2vp2         0.615   0.779  2.0    -6.454   1.0
# 1      4Vxu50qVrQcycjRyJQaZLC         0.687   0.845  7.0    -4.370   1.0
# 2      6b8Be6ljOzmkOmFslEb23P         0.818   0.803  1.0    -4.282   1.0
# 3      0afhq8XCExXpqazXczTSve         0.624   0.876  9.0    -3.374   1.0
# 4      1HNkqx9Ahdgi1Ixy2xkKkL         0.614   0.379  4.0   -10.480   1.0
# ...                       ...           ...     ...  ...       ...   ...
# 12180  5pSSEkT0963muzzIjsVkrs         0.406   0.306  3.0   -10.482   1.0
# 12181  7gC6Rbllqf1yXNC02e5jz2         0.362   0.507  1.0   -11.229   1.0
# 12182  6Ff77WXC58MkhLE5A1qgY1         0.331   0.733  2.0    -8.671   1.0
# 12183  6Ff77WXC58MkhLE5A1qgY1         0.331   0.733  2.0    -8.671   1.0
# 12184  1is5wwajEk2JW7Nsd63r3m         0.342   0.932  1.0    -3.644   1.0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.1350       0.06650  ...    0.1550    0.453  160.000
# 1           0.0576       0.10000  ...    0.0452    0.809   87.972
# 2           0.0797       0.03400  ...    0.1530    0.632  106.970
# 3           0.1000       0.07350  ...    0.3270    0.781   99.943
# 4           0.0476       0.60700  ...    0.0986    0.201  107.989
# ...            ...           ...  ...       ...      ...      ...
# 12180       0.0372       0.31300  ...    0.0727    0.073  135.272
# 12181       0.0394       0.01740  ...    0.1130    0.456  146.641
# 12182       0.0468       0.08870  ...    0.9470    0.380  128.512
# 12183       0.0468       0.08870  ...    0.9470    0.380  128.512
# 12184       0.0868       0.00106  ...    0.0938    0.226  148.148
#
#                  type                      id  \
# 0      audio_features  7zgqtptZvhf8GEmdsM2vp2
# 1      audio_features  4Vxu50qVrQcycjRyJQaZLC
# 2      audio_features  6b8Be6ljOzmkOmFslEb23P
# 3      audio_features  0afhq8XCExXpqazXczTSve
# 4      audio_features  1HNkqx9Ahdgi1Ixy2xkKkL
# ...               ...                     ...
# 12180  audio_features  5pSSEkT0963muzzIjsVkrs
# 12181  audio_features  7gC6Rbllqf1yXNC02e5jz2
# 12182  audio_features  6Ff77WXC58MkhLE5A1qgY1
# 12183  audio_features  6Ff77WXC58MkhLE5A1qgY1
# 12184  audio_features  1is5wwajEk2JW7Nsd63r3m
#
#                                         uri  \
# 0      spotify:track:7zgqtptZvhf8GEmdsM2vp2
# 1      spotify:track:4Vxu50qVrQcycjRyJQaZLC
# 2      spotify:track:6b8Be6ljOzmkOmFslEb23P
# 3      spotify:track:0afhq8XCExXpqazXczTSve
# 4      spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL
# ...                                     ...
# 12180  spotify:track:5pSSEkT0963muzzIjsVkrs
# 12181  spotify:track:7gC6Rbllqf1yXNC02e5jz2
# 12182  spotify:track:6Ff77WXC58MkhLE5A1qgY1
# 12183  spotify:track:6Ff77WXC58MkhLE5A1qgY1
# 12184  spotify:track:1is5wwajEk2JW7Nsd63r3m
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7zgqtptZvhf8...
# 1      https://api.spotify.com/v1/tracks/4Vxu50qVrQcy...
# 2      https://api.spotify.com/v1/tracks/6b8Be6ljOzmk...
# 3      https://api.spotify.com/v1/tracks/0afhq8XCExXp...
# 4      https://api.spotify.com/v1/tracks/1HNkqx9Ahdgi...
# ...                                                  ...
# 12180  https://api.spotify.com/v1/tracks/5pSSEkT0963m...
# 12181  https://api.spotify.com/v1/tracks/7gC6Rbllqf1y...
# 12182  https://api.spotify.com/v1/tracks/6Ff77WXC58Mk...
# 12183  https://api.spotify.com/v1/tracks/6Ff77WXC58Mk...
# 12184  https://api.spotify.com/v1/tracks/1is5wwajEk2J...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7zgq...    208198.0
# 1      https://api.spotify.com/v1/audio-analysis/4Vxu...    190227.0
# 2      https://api.spotify.com/v1/audio-analysis/6b8B...    225983.0
# 3      https://api.spotify.com/v1/audio-analysis/0afh...    170827.0
# 4      https://api.spotify.com/v1/audio-analysis/1HNk...    258987.0
# ...                                                  ...         ...
# 12180  https://api.spotify.com/v1/audio-analysis/5pSS...    652560.0
# 12181  https://api.spotify.com/v1/audio-analysis/7gC6...    634440.0
# 12182  https://api.spotify.com/v1/audio-analysis/6Ff7...    620747.0
# 12183  https://api.spotify.com/v1/audio-analysis/6Ff7...    620747.0
# 12184  https://api.spotify.com/v1/audio-analysis/1is5...    222107.0
#
#        time_signature
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 12180             4.0
# 12181             3.0
# 12182             4.0
# 12183             4.0
# 12184             4.0
#
# [12185 rows x 21 columns]

# %% [markdown]
# # Tercera Playlist

# %%
playlist3 = sp.user_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9")

# %%
playlist3
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6yPiKpy7evrwvZodByKvM9/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50Lr1puweM1hFsF1LpIZLM'},
#        'href': 'https://api.spotify.com/v1/artists/50Lr1puweM1hFsF1LpIZLM',
#        'id': '50Lr1puweM1hFsF1LpIZLM',
#        'name': 'WhoMadeWho',
#        'type': 'artist',
#        'uri': 'spotify:artist:50Lr1puweM1hFsF1LpIZLM'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cS5EoXVqz7aON00AkVBBA'},
#        'href': 'https://api.spotify.com/v1/artists/1cS5EoXVqz7aON00AkVBBA',
#        'id': '1cS5EoXVqz7aON00AkVBBA',
#        'name': 'DAVID AUGUST',
#        'type': 'artist',
#        'uri': 'spotify:artist:1cS5EoXVqz7aON00AkVBBA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2GvwZbDjH1DbQpodGKENDw'},
#        'href': 'https://api.spotify.com/v1/artists/2GvwZbDjH1DbQpodGKENDw',
#        'id': '2GvwZbDjH1DbQpodGKENDw',
#        'name': 'Roman Flügel',
#        'type': 'artist',
#        'uri': 'spotify:artist:2GvwZbDjH1DbQpodGKENDw'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/414VLYRvebT1LdGdI9XqsQ'},
#      'href': 'https://api.spotify.com/v1/albums/414VLYRvebT1LdGdI9XqsQ',
#      'id': '414VLYRvebT1LdGdI9XqsQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273557e119f798d685de1e84a38',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02557e119f798d685de1e84a38',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851557e119f798d685de1e84a38',
#        'width': 64}],
#      'name': 'Get Physical Music Presents: Body Language, Vol. 17 by WhoMadeWho',
#      'release_date': '2016-04-01',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:414VLYRvebT1LdGdI9XqsQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IVapwlnM3dEOiMsHXsghT'},
#       'href': 'https://api.spotify.com/v1/artists/0IVapwlnM3dEOiMsHXsghT',
#       'id': '0IVapwlnM3dEOiMsHXsghT',
#       'name': 'Nosaj Thing',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IVapwlnM3dEOiMsHXsghT'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 152560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USD8D1528015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/33xMbeHzmWd6Od0BmLZEUs'},
#     'href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#     'id': '33xMbeHzmWd6Od0BmLZEUs',
#     'is_local': False,
#     'name': '2K',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/26Fac6kNgB6MLeoGVkmpKN'},
#      'href': 'https://api.spotify.com/v1/albums/26Fac6kNgB6MLeoGVkmpKN',
#      'id': '26Fac6kNgB6MLeoGVkmpKN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a217433125ab8324ce5f7e09',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a217433125ab8324ce5f7e09',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a217433125ab8324ce5f7e09',
#        'width': 64}],
#      'name': 'Full Circle',
#      'release_date': '1972-07-17',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:26Fac6kNgB6MLeoGVkmpKN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 197706,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10609618'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3UnyplmZaq547hwsfOR5yy'},
#     'href': 'https://api.spotify.com/v1/tracks/3UnyplmZaq547hwsfOR5yy',
#     'id': '3UnyplmZaq547hwsfOR5yy',
#     'is_local': False,
#     'name': '4 Billion Souls',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d6645e0eeb0f684985c380418a5f24cc088217a6?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3UnyplmZaq547hwsfOR5yy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/36lJLPoPPOKNFddTAcirnc'},
#      'href': 'https://api.spotify.com/v1/albums/36lJLPoPPOKNFddTAcirnc',
#      'id': '36lJLPoPPOKNFddTAcirnc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27371e557eb2af8e08ec44bfc84',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0271e557eb2af8e08ec44bfc84',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485171e557eb2af8e08ec44bfc84',
#        'width': 64}],
#      'name': 'In Rainbows (Disk 2)',
#      'release_date': '2007-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:36lJLPoPPOKNFddTAcirnc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 244284,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBSTK0700018'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1w8QCSDH4QobcQeT4uMKLm'},
#     'href': 'https://api.spotify.com/v1/tracks/1w8QCSDH4QobcQeT4uMKLm',
#     'id': '1w8QCSDH4QobcQeT4uMKLm',
#     'is_local': False,
#     'name': '4 Minute Warning',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1w8QCSDH4QobcQeT4uMKLm'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UK6JkgUMa28b4t8eCtg6P'},
#        'href': 'https://api.spotify.com/v1/artists/0UK6JkgUMa28b4t8eCtg6P',
#        'id': '0UK6JkgUMa28b4t8eCtg6P',
#        'name': 'Vitas',
#        'type': 'artist',
#        'uri': 'spotify:artist:0UK6JkgUMa28b4t8eCtg6P'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0aPnQJ5p5nLwSHIQH6d5YR'},
#      'href': 'https://api.spotify.com/v1/albums/0aPnQJ5p5nLwSHIQH6d5YR',
#      'id': '0aPnQJ5p5nLwSHIQH6d5YR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a0a2d84dc57228c6e3dd9272',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a0a2d84dc57228c6e3dd9272',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a0a2d84dc57228c6e3dd9272',
#        'width': 64}],
#      'name': 'Philosophy of Miracle',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0aPnQJ5p5nLwSHIQH6d5YR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UK6JkgUMa28b4t8eCtg6P'},
#       'href': 'https://api.spotify.com/v1/artists/0UK6JkgUMa28b4t8eCtg6P',
#       'id': '0UK6JkgUMa28b4t8eCtg6P',
#       'name': 'Vitas',
#       'type': 'artist',
#       'uri': 'spotify:artist:0UK6JkgUMa28b4t8eCtg6P'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 249939,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWMA9010661'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7J9mBHG4J2eIfDAv5BehKA'},
#     'href': 'https://api.spotify.com/v1/tracks/7J9mBHG4J2eIfDAv5BehKA',
#     'id': '7J9mBHG4J2eIfDAv5BehKA',
#     'is_local': False,
#     'name': '7 Element',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7J9mBHG4J2eIfDAv5BehKA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5A5XFtOnsqgw9QzghVq5Lf'},
#      'href': 'https://api.spotify.com/v1/albums/5A5XFtOnsqgw9QzghVq5Lf',
#      'id': '5A5XFtOnsqgw9QzghVq5Lf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e3524fed78bd90e266b2d384',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e3524fed78bd90e266b2d384',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e3524fed78bd90e266b2d384',
#        'width': 64}],
#      'name': 'Instant Karma: The Amnesty International Campaign To Save Darfur [The Complete Recordings] (Audio Only)',
#      'release_date': '2007-06-11',
#      'release_date_precision': 'day',
#      'total_tracks': 61,
#      'type': 'album',
#      'uri': 'spotify:album:5A5XFtOnsqgw9QzghVq5Lf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KWTAlx2RvbpseOGMEmROg'},
#       'href': 'https://api.spotify.com/v1/artists/4KWTAlx2RvbpseOGMEmROg',
#       'id': '4KWTAlx2RvbpseOGMEmROg',
#       'name': 'R.E.M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:4KWTAlx2RvbpseOGMEmROg'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 278320,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLLZ0700007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VZedwJj1gyi88WFRhfThb'},
#     'href': 'https://api.spotify.com/v1/tracks/1VZedwJj1gyi88WFRhfThb',
#     'id': '1VZedwJj1gyi88WFRhfThb',
#     'is_local': False,
#     'name': '#9 Dream',
#     'popularity': 6,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1902adb4d960b913609e54468c8aa1c76262f03c?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 47,
#     'type': 'track',
#     'uri': 'spotify:track:1VZedwJj1gyi88WFRhfThb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5A5XFtOnsqgw9QzghVq5Lf'},
#      'href': 'https://api.spotify.com/v1/albums/5A5XFtOnsqgw9QzghVq5Lf',
#      'id': '5A5XFtOnsqgw9QzghVq5Lf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e3524fed78bd90e266b2d384',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e3524fed78bd90e266b2d384',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e3524fed78bd90e266b2d384',
#        'width': 64}],
#      'name': 'Instant Karma: The Amnesty International Campaign To Save Darfur [The Complete Recordings] (Audio Only)',
#      'release_date': '2007-06-11',
#      'release_date_precision': 'day',
#      'total_tracks': 61,
#      'type': 'album',
#      'uri': 'spotify:album:5A5XFtOnsqgw9QzghVq5Lf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jzc5TC5TVFLXQlBNiIUzE'},
#       'href': 'https://api.spotify.com/v1/artists/2jzc5TC5TVFLXQlBNiIUzE',
#       'id': '2jzc5TC5TVFLXQlBNiIUzE',
#       'name': 'a-ha',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jzc5TC5TVFLXQlBNiIUzE'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 247066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLLZ0700013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3DSmOF7ETJHAQEqqgoSJao'},
#     'href': 'https://api.spotify.com/v1/tracks/3DSmOF7ETJHAQEqqgoSJao',
#     'id': '3DSmOF7ETJHAQEqqgoSJao',
#     'is_local': False,
#     'name': '#9 Dream',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/93ac7246798378d792708f6b0706b4f697a76774?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3DSmOF7ETJHAQEqqgoSJao'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#        'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#        'id': '7mnBLXK823vNxN3UWB7Gfz',
#        'name': 'The Black Keys',
#        'type': 'artist',
#        'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'HT',
#       'JM',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'FM',
#       'NA',
#       'NE',
#       'PG',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'KN',
#       'LC',
#       'VC',
#       'TL',
#       'TT',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TvxpBzf9c8H1fsrAaQ8t3'},
#      'href': 'https://api.spotify.com/v1/albums/6TvxpBzf9c8H1fsrAaQ8t3',
#      'id': '6TvxpBzf9c8H1fsrAaQ8t3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731af8fb0d8859055d35d2290f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021af8fb0d8859055d35d2290f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511af8fb0d8859055d35d2290f',
#        'width': 64}],
#      'name': 'Turn Blue',
#      'release_date': '2014-05-09',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6TvxpBzf9c8H1fsrAaQ8t3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#       'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#       'id': '7mnBLXK823vNxN3UWB7Gfz',
#       'name': 'The Black Keys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 213226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNO11400185'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5HPnumlogzZtpLEaORZjz1'},
#     'href': 'https://api.spotify.com/v1/tracks/5HPnumlogzZtpLEaORZjz1',
#     'id': '5HPnumlogzZtpLEaORZjz1',
#     'is_local': False,
#     'name': '10 Lovers',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f557228ac0c69465d8d70bc9ed2520f2b222ef83?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5HPnumlogzZtpLEaORZjz1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rAv1GhTQ2rmG94p9lU3rB'},
#        'href': 'https://api.spotify.com/v1/artists/1rAv1GhTQ2rmG94p9lU3rB',
#        'id': '1rAv1GhTQ2rmG94p9lU3rB',
#        'name': 'Julian Casablancas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rAv1GhTQ2rmG94p9lU3rB'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4rP54hT8fzDosnCtzQyBRF'},
#      'href': 'https://api.spotify.com/v1/albums/4rP54hT8fzDosnCtzQyBRF',
#      'id': '4rP54hT8fzDosnCtzQyBRF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7eae07761b35ca163d75ef0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7eae07761b35ca163d75ef0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7eae07761b35ca163d75ef0',
#        'width': 64}],
#      'name': 'Phrazes For The Young',
#      'release_date': '2009-10-30',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4rP54hT8fzDosnCtzQyBRF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rAv1GhTQ2rmG94p9lU3rB'},
#       'href': 'https://api.spotify.com/v1/artists/1rAv1GhTQ2rmG94p9lU3rB',
#       'id': '1rAv1GhTQ2rmG94p9lU3rB',
#       'name': 'Julian Casablancas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rAv1GhTQ2rmG94p9lU3rB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 243333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC10900512'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6i99ThziImjuFABb8rUQvy'},
#     'href': 'https://api.spotify.com/v1/tracks/6i99ThziImjuFABb8rUQvy',
#     'id': '6i99ThziImjuFABb8rUQvy',
#     'is_local': False,
#     'name': '11th Dimension',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fe9f7321b6cf417d08f1d6be7600ace7d8ccdd64?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6i99ThziImjuFABb8rUQvy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#        'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#        'id': '0epOFNiUfyON9EYx7Tpr6V',
#        'name': 'The Strokes',
#        'type': 'artist',
#        'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5OA9iN6WTzunqAdiuEpr7Q'},
#      'href': 'https://api.spotify.com/v1/albums/5OA9iN6WTzunqAdiuEpr7Q',
#      'id': '5OA9iN6WTzunqAdiuEpr7Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273980f5c89ec28d7510487a843',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02980f5c89ec28d7510487a843',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851980f5c89ec28d7510487a843',
#        'width': 64}],
#      'name': 'Room On Fire',
#      'release_date': '2003-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5OA9iN6WTzunqAdiuEpr7Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 153133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC10301489'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0nkLI0pdyTRpq7BsTFBufZ'},
#     'href': 'https://api.spotify.com/v1/tracks/0nkLI0pdyTRpq7BsTFBufZ',
#     'id': '0nkLI0pdyTRpq7BsTFBufZ',
#     'is_local': False,
#     'name': '12:51',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0nkLI0pdyTRpq7BsTFBufZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#        'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#        'id': '0epOFNiUfyON9EYx7Tpr6V',
#        'name': 'The Strokes',
#        'type': 'artist',
#        'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3HFbH1loOUbqCyPsLuHLLh'},
#      'href': 'https://api.spotify.com/v1/albums/3HFbH1loOUbqCyPsLuHLLh',
#      'id': '3HFbH1loOUbqCyPsLuHLLh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f35726025e0f025da4c688f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f35726025e0f025da4c688f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f35726025e0f025da4c688f',
#        'width': 64}],
#      'name': 'Room On Fire',
# ...
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 188800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC10100770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pXyK9GW7fuT645U0DLYYF'},
#     'href': 'https://api.spotify.com/v1/tracks/4pXyK9GW7fuT645U0DLYYF',
#     'id': '4pXyK9GW7fuT645U0DLYYF',
#     'is_local': False,
#     'name': 'Alone, Together',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8655c6f2741165413be0926dd7d0bec112403a8f?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4pXyK9GW7fuT645U0DLYYF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#        'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#        'id': '0epOFNiUfyON9EYx7Tpr6V',
#        'name': 'The Strokes',
#        'type': 'artist',
#        'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2k8KgmDp9oHrmu0MIj4XDE'},
#      'href': 'https://api.spotify.com/v1/albums/2k8KgmDp9oHrmu0MIj4XDE',
#      'id': '2k8KgmDp9oHrmu0MIj4XDE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313f2466b83507515291acce4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213f2466b83507515291acce4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113f2466b83507515291acce4',
#        'width': 64}],
#      'name': 'Is This It',
#      'release_date': '2001-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2k8KgmDp9oHrmu0MIj4XDE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 188640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC10100770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4UmJMAY5TqXPAnsDW1Mci7'},
#     'href': 'https://api.spotify.com/v1/tracks/4UmJMAY5TqXPAnsDW1Mci7',
#     'id': '4UmJMAY5TqXPAnsDW1Mci7',
#     'is_local': False,
#     'name': 'Alone, Together',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8655c6f2741165413be0926dd7d0bec112403a8f?cid=b35686352f9e49b8ae7bb2da09f64419',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4UmJMAY5TqXPAnsDW1Mci7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MXUO7sVCaFgFjoTI5ox5c'},
#        'href': 'https://api.spotify.com/v1/artists/4MXUO7sVCaFgFjoTI5ox5c',
#        'id': '4MXUO7sVCaFgFjoTI5ox5c',
#        'name': 'Sufjan Stevens',
#        'type': 'artist',
#        'uri': 'spotify:artist:4MXUO7sVCaFgFjoTI5ox5c'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0AVvBrOZ4Hy3yCW8SguJLy'},
#      'href': 'https://api.spotify.com/v1/albums/0AVvBrOZ4Hy3yCW8SguJLy',
#      'id': '0AVvBrOZ4Hy3yCW8SguJLy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cec0767c5c65a58b1a97eb7f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cec0767c5c65a58b1a97eb7f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cec0767c5c65a58b1a97eb7f',
#        'width': 64}],
#      'name': 'Silver & Gold',
#      'release_date': '2012-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 58,
#      'type': 'album',
#      'uri': 'spotify:album:0AVvBrOZ4Hy3yCW8SguJLy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MXUO7sVCaFgFjoTI5ox5c'},
#       'href': 'https://api.spotify.com/v1/artists/4MXUO7sVCaFgFjoTI5ox5c',
#       'id': '4MXUO7sVCaFgFjoTI5ox5c',
#       'name': 'Sufjan Stevens',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MXUO7sVCaFgFjoTI5ox5c'}],
#     'available_markets': [],
#     'disc_number': 3,
#     'duration_ms': 96293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US64G1210037'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/13Q8MH3xSfIyXSVIQpIl8H'},
#     'href': 'https://api.spotify.com/v1/tracks/13Q8MH3xSfIyXSVIQpIl8H',
#     'id': '13Q8MH3xSfIyXSVIQpIl8H',
#     'is_local': False,
#     'name': 'Alphabet St.',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:13Q8MH3xSfIyXSVIQpIl8H'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#        'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#        'id': '4C50EbCS11M0VbGyH3OfLt',
#        'name': 'Bahamas',
#        'type': 'artist',
#        'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#      'available_markets': ['CA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6bu0SsAMxliMaKXc82MNZN'},
#      'href': 'https://api.spotify.com/v1/albums/6bu0SsAMxliMaKXc82MNZN',
#      'id': '6bu0SsAMxliMaKXc82MNZN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731bb6875c0f94f6a52a94d792',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021bb6875c0f94f6a52a94d792',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511bb6875c0f94f6a52a94d792',
#        'width': 64}],
#      'name': 'Pink Strat',
#      'release_date': '2009-07-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6bu0SsAMxliMaKXc82MNZN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4C50EbCS11M0VbGyH3OfLt'},
#       'href': 'https://api.spotify.com/v1/artists/4C50EbCS11M0VbGyH3OfLt',
#       'id': '4C50EbCS11M0VbGyH3OfLt',
#       'name': 'Bahamas',
#       'type': 'artist',
#       'uri': 'spotify:artist:4C50EbCS11M0VbGyH3OfLt'}],
#     'available_markets': ['CA'],
#     'disc_number': 1,
#     'duration_ms': 125546,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAND60800078'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6gyUiLI8CLSy9UIAiHcJ2j'},
#     'href': 'https://api.spotify.com/v1/tracks/6gyUiLI8CLSy9UIAiHcJ2j',
#     'id': '6gyUiLI8CLSy9UIAiHcJ2j',
#     'is_local': False,
#     'name': 'Already Yours',
#     'popularity': 11,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6gyUiLI8CLSy9UIAiHcJ2j'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#        'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#        'id': '5INjqkS1o8h1imAzPqGZBb',
#        'name': 'Tame Impala',
#        'type': 'artist',
#        'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5RA5hhLlbw31QfQRX11pwo'},
#      'href': 'https://api.spotify.com/v1/albums/5RA5hhLlbw31QfQRX11pwo',
#      'id': '5RA5hhLlbw31QfQRX11pwo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd6ec171d9acdb315ff81610',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd6ec171d9acdb315ff81610',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd6ec171d9acdb315ff81610',
#        'width': 64}],
#      'name': 'InnerSpeaker',
#      'release_date': '2010-05-21',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5RA5hhLlbw31QfQRX11pwo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#       'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#       'id': '5INjqkS1o8h1imAzPqGZBb',
#       'name': 'Tame Impala',
#       'type': 'artist',
#       'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 287613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUUM71000133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Zy9cf5v1tWFDmXTbahAU8'},
#     'href': 'https://api.spotify.com/v1/tracks/2Zy9cf5v1tWFDmXTbahAU8',
#     'id': '2Zy9cf5v1tWFDmXTbahAU8',
#     'is_local': False,
#     'name': 'Alter Ego',
#     'popularity': 43,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2Zy9cf5v1tWFDmXTbahAU8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#        'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#        'id': '16GcWuvvybAoaHr0NqT8Eh',
#        'name': 'Alabama Shakes',
#        'type': 'artist',
#        'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4vj1CTKvVa5BEoTADUFboE'},
#      'href': 'https://api.spotify.com/v1/albums/4vj1CTKvVa5BEoTADUFboE',
#      'id': '4vj1CTKvVa5BEoTADUFboE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ed9f08ed2c4c726e8c581',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ed9f08ed2c4c726e8c581',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ed9f08ed2c4c726e8c581',
#        'width': 64}],
#      'name': 'Always Alright',
#      'release_date': '2013-12-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4vj1CTKvVa5BEoTADUFboE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 249169,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USATO1200309'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/17Jg504RgNPNgdpRkJh9Co'},
#     'href': 'https://api.spotify.com/v1/tracks/17Jg504RgNPNgdpRkJh9Co',
#     'id': '17Jg504RgNPNgdpRkJh9Co',
#     'is_local': False,
#     'name': 'Always Alright',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:17Jg504RgNPNgdpRkJh9Co'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26T3LtbuGT1Fu9m0eRq5X3'},
#        'href': 'https://api.spotify.com/v1/artists/26T3LtbuGT1Fu9m0eRq5X3',
#        'id': '26T3LtbuGT1Fu9m0eRq5X3',
#        'name': 'Cage The Elephant',
#        'type': 'artist',
#        'uri': 'spotify:artist:26T3LtbuGT1Fu9m0eRq5X3'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3eGL4oa233BAecE9cGZI4k'},
#      'href': 'https://api.spotify.com/v1/albums/3eGL4oa233BAecE9cGZI4k',
#      'id': '3eGL4oa233BAecE9cGZI4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27311ef2676331cfe842ac4576b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0211ef2676331cfe842ac4576b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485111ef2676331cfe842ac4576b',
#        'width': 64}],
#      'name': 'Thank You Happy Birthday',
#      'release_date': '2011',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3eGL4oa233BAecE9cGZI4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26T3LtbuGT1Fu9m0eRq5X3'},
#       'href': 'https://api.spotify.com/v1/artists/26T3LtbuGT1Fu9m0eRq5X3',
#       'id': '26T3LtbuGT1Fu9m0eRq5X3',
#       'name': 'Cage The Elephant',
#       'type': 'artist',
#       'uri': 'spotify:artist:26T3LtbuGT1Fu9m0eRq5X3'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 221946,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI11000265'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7lWrbqRzkjLIv9SGHUDDnL'},
#     'href': 'https://api.spotify.com/v1/tracks/7lWrbqRzkjLIv9SGHUDDnL',
#     'id': '7lWrbqRzkjLIv9SGHUDDnL',
#     'is_local': False,
#     'name': 'Always Something',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7lWrbqRzkjLIv9SGHUDDnL'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/6yPiKpy7evrwvZodByKvM9/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 10000}

# %%
playlist3.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist3["total"]
# Out:
# 10000

# %%
playlist3['next']
# Out:
# 'https://api.spotify.com/v1/playlists/6yPiKpy7evrwvZodByKvM9/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks3 = get_playlist_tracks("6yPiKpy7evrwvZodByKvM9")
len(all_tracks3)
# Out:
# 10000

# %%
tracks22 = json_normalize(all_tracks3)

# %%
tracks22.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-02-27T01:38:09Z     False          None
# 1  2017-02-27T01:38:09Z     False          None
# 2  2017-02-27T01:38:09Z     False          None
# 3  2017-02-27T01:38:09Z     False          None
# 4  2017-02-27T01:38:09Z     False          None
#
#               added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/12160726861
# 1  https://open.spotify.com/user/12160726861
# 2  https://open.spotify.com/user/12160726861
# 3  https://open.spotify.com/user/12160726861
# 4  https://open.spotify.com/user/12160726861
#
#                                   added_by.href  added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 1  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 2  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 3  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 4  https://api.spotify.com/v1/users/12160726861  12160726861          user
#
#                added_by.uri track.album.album_type  \
# 0  spotify:user:12160726861                  album
# 1  spotify:user:12160726861                  album
# 2  spotify:user:12160726861                  album
# 3  spotify:user:12160726861                  album
# 4  spotify:user:12160726861            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local        track.name track.popularity  \
# 0  33xMbeHzmWd6Od0BmLZEUs          False                2K                0
# 1  3UnyplmZaq547hwsfOR5yy          False   4 Billion Souls               25
# 2  1w8QCSDH4QobcQeT4uMKLm          False  4 Minute Warning                0
# 3  7J9mBHG4J2eIfDAv5BehKA          False         7 Element                0
# 4  1VZedwJj1gyi88WFRhfThb          False          #9 Dream                6
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/d6645e0eeb0f6849...        True
# 2                                               None        True
# 3                                               None        True
# 4  https://p.scdn.co/mp3-preview/1902adb4d960b913...        True
#
#   track.track_number track.type                             track.uri  \
# 0                 17      track  spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1                  2      track  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2                  8      track  spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3                  2      track  spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4                 47      track  spotify:track:1VZedwJj1gyi88WFRhfThb
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
# we can even create a new column containing these DataFrames! KEEP song URI
# NOTE: need to change this function, since the columns names are now a bit different
def expand_list_dict2(row):
    df3 = json_normalize(row['track.artists'])
    df3['song_id'] = row['track.id']
    return df3

tracks22['artists_dfs'] = tracks22.apply(expand_list_dict2, axis=1)
tracks22['artists_dfs'][3]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
#
#     name    type                                    uri  \
# 0  Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA

# %%
# now we create a new dataframe with all these artists
artist_df22 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
for mini_df3 in tracks22['artists_dfs']:
    #display(val)
    artist_df22 = pd.concat([artist_df22, mini_df3], axis=0)
    
artist_df22
# Out:
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/0IVapwlnM3d...  0IVapwlnM3dEOiMsHXsghT
# 0   https://api.spotify.com/v1/artists/22WZ7M8sxp5...  22WZ7M8sxp5THdruNY3gXt
# 0   https://api.spotify.com/v1/artists/4Z8W4fKeB5Y...  4Z8W4fKeB5YxbusRsdQVPb
# 0   https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
# 0   https://api.spotify.com/v1/artists/4KWTAlx2Rvb...  4KWTAlx2RvbpseOGMEmROg
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/3RGLhK1IP9j...  3RGLhK1IP9jnYFH4BRFJBS
# 0   https://api.spotify.com/v1/artists/3ICyfoySNDZ...  3ICyfoySNDZqtBVmaBT84I
# 0   https://api.spotify.com/v1/artists/3OsRAKCvk37...  3OsRAKCvk37zwYcnzRf5XF
# 0   https://api.spotify.com/v1/artists/023YMawCG3O...  023YMawCG3OvACmRjWxLWC
# 0   https://api.spotify.com/v1/artists/2pH3wEn4eYl...  2pH3wEn4eYlMMIIQyKPbVR
#
#               name    type                                    uri  \
# 0      Nosaj Thing  artist  spotify:artist:0IVapwlnM3dEOiMsHXsghT
# 0        The Doors  artist  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 0        Radiohead  artist  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# 0            Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
# 0           R.E.M.  artist  spotify:artist:4KWTAlx2RvbpseOGMEmROg
# ..             ...     ...                                    ...
# 0        The Clash  artist  spotify:artist:3RGLhK1IP9jnYFH4BRFJBS
# 0              War  artist  spotify:artist:3ICyfoySNDZqtBVmaBT84I
# 0             Moby  artist  spotify:artist:3OsRAKCvk37zwYcnzRf5XF
# 0   The Cat Empire  artist  spotify:artist:023YMawCG3OvACmRjWxLWC
# 0      DragonForce  artist  spotify:artist:2pH3wEn4eYlMMIIQyKPbVR
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/0IVapwlnM3dEOi...  33xMbeHzmWd6Od0BmLZEUs
# 0   https://open.spotify.com/artist/22WZ7M8sxp5THd...  3UnyplmZaq547hwsfOR5yy
# 0   https://open.spotify.com/artist/4Z8W4fKeB5Yxbu...  1w8QCSDH4QobcQeT4uMKLm
# 0   https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA
# 0   https://open.spotify.com/artist/4KWTAlx2Rvbpse...  1VZedwJj1gyi88WFRhfThb
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/3RGLhK1IP9jnYF...  5jzma6gCzYtKB1DbEwFZKH
# 0   https://open.spotify.com/artist/3ICyfoySNDZqtB...  2fmMPJb5EzZCx8BcNJvVk4
# 0   https://open.spotify.com/artist/3OsRAKCvk37zwY...  60rIdEPDrzyLiLC0icp3xz
# 0   https://open.spotify.com/artist/023YMawCG3OvAC...  0sEm1ld0V8YTCPcjPVfIsc
# 0   https://open.spotify.com/artist/2pH3wEn4eYlMMI...  4JPE3Q7vuFa6UFoduMgZm2
#
# [11854 rows x 7 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged22 = pd.merge(left=tracks22,
                    right=artist_df22,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged22.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-02-27T01:38:09Z     False          None
# 1  2017-02-27T01:38:09Z     False          None
# 2  2017-02-27T01:38:09Z     False          None
# 3  2017-02-27T01:38:09Z     False          None
# 4  2017-02-27T01:38:09Z     False          None
#
#               added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/12160726861
# 1  https://open.spotify.com/user/12160726861
# 2  https://open.spotify.com/user/12160726861
# 3  https://open.spotify.com/user/12160726861
# 4  https://open.spotify.com/user/12160726861
#
#                                   added_by.href  added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 1  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 2  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 3  https://api.spotify.com/v1/users/12160726861  12160726861          user
# 4  https://api.spotify.com/v1/users/12160726861  12160726861          user
#
#                added_by.uri track.album.album_type  \
# 0  spotify:user:12160726861                  album
# 1  spotify:user:12160726861                  album
# 2  spotify:user:12160726861                  album
# 3  spotify:user:12160726861                  album
# 4  spotify:user:12160726861            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:33xMbeHzmWd6Od0BmLZEUs                None
# 1  spotify:track:3UnyplmZaq547hwsfOR5yy                None
# 2  spotify:track:1w8QCSDH4QobcQeT4uMKLm                None
# 3  spotify:track:7J9mBHG4J2eIfDAv5BehKA                None
# 4  spotify:track:1VZedwJj1gyi88WFRhfThb                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/0IVapwlnM3d...  0IVapwlnM3dEOiMsHXsghT
# 1  https://api.spotify.com/v1/artists/22WZ7M8sxp5...  22WZ7M8sxp5THdruNY3gXt
# 2  https://api.spotify.com/v1/artists/4Z8W4fKeB5Y...  4Z8W4fKeB5YxbusRsdQVPb
# 3  https://api.spotify.com/v1/artists/0UK6JkgUMa2...  0UK6JkgUMa28b4t8eCtg6P
# 4  https://api.spotify.com/v1/artists/4KWTAlx2Rvb...  4KWTAlx2RvbpseOGMEmROg
#
#           name    type                                    uri  \
# 0  Nosaj Thing  artist  spotify:artist:0IVapwlnM3dEOiMsHXsghT
# 1    The Doors  artist  spotify:artist:22WZ7M8sxp5THdruNY3gXt
# 2    Radiohead  artist  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# 3        Vitas  artist  spotify:artist:0UK6JkgUMa28b4t8eCtg6P
# 4       R.E.M.  artist  spotify:artist:4KWTAlx2RvbpseOGMEmROg
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/0IVapwlnM3dEOi...  33xMbeHzmWd6Od0BmLZEUs
# 1  https://open.spotify.com/artist/22WZ7M8sxp5THd...  3UnyplmZaq547hwsfOR5yy
# 2  https://open.spotify.com/artist/4Z8W4fKeB5Yxbu...  1w8QCSDH4QobcQeT4uMKLm
# 3  https://open.spotify.com/artist/0UK6JkgUMa28b4...  7J9mBHG4J2eIfDAv5BehKA
# 4  https://open.spotify.com/artist/4KWTAlx2Rvbpse...  1VZedwJj1gyi88WFRhfThb
#
# [5 rows x 48 columns]

# %%
df_final22 = df_merged22[['track.name', 'name', 'song_id']]
df_final22
# Out:
#                         track.name            name                 song_id
# 0                               2K     Nosaj Thing  33xMbeHzmWd6Od0BmLZEUs
# 1                  4 Billion Souls       The Doors  3UnyplmZaq547hwsfOR5yy
# 2                 4 Minute Warning       Radiohead  1w8QCSDH4QobcQeT4uMKLm
# 3                        7 Element           Vitas  7J9mBHG4J2eIfDAv5BehKA
# 4                         #9 Dream          R.E.M.  1VZedwJj1gyi88WFRhfThb
# ...                            ...             ...                     ...
# 18591  London Calling - Remastered       The Clash  5jzma6gCzYtKB1DbEwFZKH
# 18592                    Low Rider             War  2fmMPJb5EzZCx8BcNJvVk4
# 18593                       Flower            Moby  60rIdEPDrzyLiLC0icp3xz
# 18594           Brighter Than Gold  The Cat Empire  0sEm1ld0V8YTCPcjPVfIsc
# 18595     Fury of the Storm - Live     DragonForce  4JPE3Q7vuFa6UFoduMgZm2
#
# [18596 rows x 3 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final22), 100)]
chunks
audio_features_list2 = []
for chunk in chunks:
    df_final22['song_id'] = df_final22['song_id'].astype(str)
    id3_list100 = df_final22['song_id'][chunk[0]:chunk[1]]
    audio_features_list2 = audio_features_list2 + sp.audio_features(id3_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list2)
# Out:
# /var/folders/d9/_ctzl6l91nb3xf6zfxnk4py80000gn/T/ipykernel_18873/232225502.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final22['song_id'] = df_final22['song_id'].astype(str)
# 18596

# %%
audio_features_df2 = json_normalize(audio_features_list2)

# %%
audio_features_df2.drop_duplicates(inplace=True) # duplicates because some songs have more artists

# %%
df_w_audio_ft2 = pd.merge(left=df_final22,
                        right=audio_features_df2,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft2
# Out:
#                         track.name            name                 song_id  \
# 0                               2K     Nosaj Thing  33xMbeHzmWd6Od0BmLZEUs
# 1                  4 Billion Souls       The Doors  3UnyplmZaq547hwsfOR5yy
# 2                 4 Minute Warning       Radiohead  1w8QCSDH4QobcQeT4uMKLm
# 3                        7 Element           Vitas  7J9mBHG4J2eIfDAv5BehKA
# 4                         #9 Dream          R.E.M.  1VZedwJj1gyi88WFRhfThb
# ...                            ...             ...                     ...
# 11867  London Calling - Remastered       The Clash  5jzma6gCzYtKB1DbEwFZKH
# 11868                    Low Rider             War  2fmMPJb5EzZCx8BcNJvVk4
# 11869                       Flower            Moby  60rIdEPDrzyLiLC0icp3xz
# 11870           Brighter Than Gold  The Cat Empire  0sEm1ld0V8YTCPcjPVfIsc
# 11871     Fury of the Storm - Live     DragonForce  4JPE3Q7vuFa6UFoduMgZm2
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.310   0.445  7.0   -13.355   0.0       0.0863       0.09400
# 1             0.419   0.565  5.0   -11.565   1.0       0.0347       0.13700
# 2             0.354   0.302  9.0   -13.078   1.0       0.0326       0.59000
# 3             0.727   0.785  5.0    -6.707   0.0       0.0603       0.32500
# 4             0.571   0.724  0.0    -5.967   1.0       0.0260       0.02310
# ...             ...     ...  ...       ...   ...          ...           ...
# 11867         0.651   0.801  0.0    -7.340   1.0       0.0514       0.12300
# 11868         0.811   0.647  0.0   -10.989   1.0       0.0498       0.08230
# 11869         0.686   0.610  7.0    -5.902   1.0       0.0262       0.19000
# 11870         0.711   0.718  6.0    -5.739   1.0       0.0380       0.00824
# 11871         0.323   0.997  1.0    -3.440   1.0       0.2640       0.00767
#
#        ...  liveness  valence    tempo            type  \
# 0      ...    0.1130    0.122   95.360  audio_features
# 1      ...    0.1280    0.648  151.277  audio_features
# 2      ...    0.1110    0.223  123.753  audio_features
# 3      ...    0.3100    0.960  129.649  audio_features
# 4      ...    0.0919    0.385  116.755  audio_features
# ...    ...       ...      ...      ...             ...
# 11867  ...    0.0825    0.776  133.769  audio_features
# 11868  ...    0.0572    0.990  139.787  audio_features
# 11869  ...    0.0710    0.766   80.567  audio_features
# 11870  ...    0.0732    0.688  117.071  audio_features
# 11871  ...    0.9480    0.315  199.962  audio_features
#
#                            id                                   uri  \
# 0      33xMbeHzmWd6Od0BmLZEUs  spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1      3UnyplmZaq547hwsfOR5yy  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2      1w8QCSDH4QobcQeT4uMKLm  spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3      7J9mBHG4J2eIfDAv5BehKA  spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4      1VZedwJj1gyi88WFRhfThb  spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                       ...                                   ...
# 11867  5jzma6gCzYtKB1DbEwFZKH  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 11868  2fmMPJb5EzZCx8BcNJvVk4  spotify:track:2fmMPJb5EzZCx8BcNJvVk4
# 11869  60rIdEPDrzyLiLC0icp3xz  spotify:track:60rIdEPDrzyLiLC0icp3xz
# 11870  0sEm1ld0V8YTCPcjPVfIsc  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 11871  4JPE3Q7vuFa6UFoduMgZm2  spotify:track:4JPE3Q7vuFa6UFoduMgZm2
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1      https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2      https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3      https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4      https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                  ...
# 11867  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 11868  https://api.spotify.com/v1/tracks/2fmMPJb5EzZC...
# 11869  https://api.spotify.com/v1/tracks/60rIdEPDrzyL...
# 11870  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 11871  https://api.spotify.com/v1/tracks/4JPE3Q7vuFa6...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/33xM...    152560.0
# 1      https://api.spotify.com/v1/audio-analysis/3Uny...    197707.0
# 2      https://api.spotify.com/v1/audio-analysis/1w8Q...    244285.0
# 3      https://api.spotify.com/v1/audio-analysis/7J9m...    249940.0
# 4      https://api.spotify.com/v1/audio-analysis/1VZe...    278320.0
# ...                                                  ...         ...
# 11867  https://api.spotify.com/v1/audio-analysis/5jzm...    200480.0
# 11868  https://api.spotify.com/v1/audio-analysis/2fmM...    191560.0
# 11869  https://api.spotify.com/v1/audio-analysis/60rI...    206293.0
# 11870  https://api.spotify.com/v1/audio-analysis/0sEm...    200293.0
# 11871  https://api.spotify.com/v1/audio-analysis/4JPE...    409013.0
#
#        time_signature
# 0                 3.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 11867             4.0
# 11868             4.0
# 11869             4.0
# 11870             4.0
# 11871             4.0
#
# [11872 rows x 21 columns]

# %%
df_w_audio_ftotal = pd.concat([df_w_audio_ft, df_w_audio_ft1, df_w_audio_ft2], axis=0, ignore_index=True)

df_w_audio_ftotal
# Out:
#                         track.name            name                 song_id  \
# 0            If I Ever Feel Better         Phoenix  3AA8xNhDC0MpqwkGX3EP5V
# 1         Dance To The Underground         Radio 4  2i8lRhmZNKaM1ypHwRybuD
# 2                        How We Do      Mount Sims  4flxgPC0426CEeSrzQIic0
# 3               Fuck the Pain Away         Peaches  1XHFob24QklIXtLRopKirJ
# 4                 Street Surgery 2        Zongamin  4JB847zlgViLq8tJIzRsZy
# ...                            ...             ...                     ...
# 36733  London Calling - Remastered       The Clash  5jzma6gCzYtKB1DbEwFZKH
# 36734                    Low Rider             War  2fmMPJb5EzZCx8BcNJvVk4
# 36735                       Flower            Moby  60rIdEPDrzyLiLC0icp3xz
# 36736           Brighter Than Gold  The Cat Empire  0sEm1ld0V8YTCPcjPVfIsc
# 36737     Fury of the Storm - Live     DragonForce  4JPE3Q7vuFa6UFoduMgZm2
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.755   0.553   6.0    -9.449   0.0       0.1070       0.04920
# 1             0.667   0.667   7.0    -6.267   1.0       0.0388       0.00013
# 2             0.826   0.601  10.0    -3.966   0.0       0.0515       0.19500
# 3             0.905   0.945   4.0    -2.630   1.0       0.1370       0.03540
# 4             0.797   0.536  11.0    -8.267   0.0       0.2660       0.03150
# ...             ...     ...   ...       ...   ...          ...           ...
# 36733         0.651   0.801   0.0    -7.340   1.0       0.0514       0.12300
# 36734         0.811   0.647   0.0   -10.989   1.0       0.0498       0.08230
# 36735         0.686   0.610   7.0    -5.902   1.0       0.0262       0.19000
# 36736         0.711   0.718   6.0    -5.739   1.0       0.0380       0.00824
# 36737         0.323   0.997   1.0    -3.440   1.0       0.2640       0.00767
#
#        ...  liveness  valence    tempo            type  \
# 0      ...    0.0646    0.836  119.700  audio_features
# 1      ...    0.0711    0.843  130.321  audio_features
# 2      ...    0.0700    0.948  126.971  audio_features
# 3      ...    0.0707    0.944  131.597  audio_features
# 4      ...    0.1700    0.704  102.881  audio_features
# ...    ...       ...      ...      ...             ...
# 36733  ...    0.0825    0.776  133.769  audio_features
# 36734  ...    0.0572    0.990  139.787  audio_features
# 36735  ...    0.0710    0.766   80.567  audio_features
# 36736  ...    0.0732    0.688  117.071  audio_features
# 36737  ...    0.9480    0.315  199.962  audio_features
#
#                            id                                   uri  \
# 0      3AA8xNhDC0MpqwkGX3EP5V  spotify:track:3AA8xNhDC0MpqwkGX3EP5V
# 1      2i8lRhmZNKaM1ypHwRybuD  spotify:track:2i8lRhmZNKaM1ypHwRybuD
# 2      4flxgPC0426CEeSrzQIic0  spotify:track:4flxgPC0426CEeSrzQIic0
# 3      1XHFob24QklIXtLRopKirJ  spotify:track:1XHFob24QklIXtLRopKirJ
# 4      4JB847zlgViLq8tJIzRsZy  spotify:track:4JB847zlgViLq8tJIzRsZy
# ...                       ...                                   ...
# 36733  5jzma6gCzYtKB1DbEwFZKH  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 36734  2fmMPJb5EzZCx8BcNJvVk4  spotify:track:2fmMPJb5EzZCx8BcNJvVk4
# 36735  60rIdEPDrzyLiLC0icp3xz  spotify:track:60rIdEPDrzyLiLC0icp3xz
# 36736  0sEm1ld0V8YTCPcjPVfIsc  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 36737  4JPE3Q7vuFa6UFoduMgZm2  spotify:track:4JPE3Q7vuFa6UFoduMgZm2
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3AA8xNhDC0Mp...
# 1      https://api.spotify.com/v1/tracks/2i8lRhmZNKaM...
# 2      https://api.spotify.com/v1/tracks/4flxgPC0426C...
# 3      https://api.spotify.com/v1/tracks/1XHFob24QklI...
# 4      https://api.spotify.com/v1/tracks/4JB847zlgViL...
# ...                                                  ...
# 36733  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 36734  https://api.spotify.com/v1/tracks/2fmMPJb5EzZC...
# 36735  https://api.spotify.com/v1/tracks/60rIdEPDrzyL...
# 36736  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 36737  https://api.spotify.com/v1/tracks/4JPE3Q7vuFa6...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3AA8...    266600.0
# 1      https://api.spotify.com/v1/audio-analysis/2i8l...    243213.0
# 2      https://api.spotify.com/v1/audio-analysis/4flx...    234000.0
# 3      https://api.spotify.com/v1/audio-analysis/1XHF...    250693.0
# 4      https://api.spotify.com/v1/audio-analysis/4JB8...    224800.0
# ...                                                  ...         ...
# 36733  https://api.spotify.com/v1/audio-analysis/5jzm...    200480.0
# 36734  https://api.spotify.com/v1/audio-analysis/2fmM...    191560.0
# 36735  https://api.spotify.com/v1/audio-analysis/60rI...    206293.0
# 36736  https://api.spotify.com/v1/audio-analysis/0sEm...    200293.0
# 36737  https://api.spotify.com/v1/audio-analysis/4JPE...    409013.0
#
#        time_signature
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 36733             4.0
# 36734             4.0
# 36735             4.0
# 36736             4.0
# 36737             4.0
#
# [36738 rows x 21 columns]
